# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using Selenium for this, *not* BeautifulSoup and requests.

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.tdlr.texas.gov/cimsfo/fosearch.asp")

# %%
driver.page_source
# Out:
# '<html lang="en" class=" supports csstransforms3d"><head>\n    <title>Administrative Orders - Search</title>\n    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n\t<link rel="shortcut icon" href="/images/favicon.png" type="image/x-icon">\n\n    <!-- Google Tag Manager -->\n    <script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-MPP5WF5"></script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n    new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n    j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n    \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n    })(window,document,\'script\',\'dataLayer\',\'GTM-MPP5WF5\');</script>\n    <!-- End Google Tag Manager -->\n\n\t<link type="text/css" rel="stylesheet" href="/css/reset.css">\n\t<link type="text/css" rel="stylesheet" href="/css/font-awesome.min.css">\n\t<link type="text/css" rel="stylesheet" href="/css/animate.css">\n\t<link type="text/css" rel="stylesheet" href="/css/main-stylesheet.css">\n\t<link type="text/css" rel="stylesheet" href="/css/lightbox.css">\n\t<link type="text/css" rel="stylesheet" href="/css/shortcodes.css">\n\t<link type="text/css" rel="stylesheet" href="/css/custom-fonts.css">\n\t<link type="text/css" rel="stylesheet" href="/css/custom-colors.css">\n\t<link type="text/css" rel="stylesheet" href="/css/responsive.css">\n\t<link type="text/css" rel="stylesheet" href="/css/dat-menu.css">\n    <link rel="stylesheet" type="text/css" href="css/fosearch.css">\n\t<!--[if lte IE 8]>\n\t<link type="text/css" rel="stylesheet" href="/css/ie-ancient.css" />\n\t<![endif]-->\n    <script type="text/javascript" src="js/app.js"></script>\n</head>\n<body class="ot-menu-ipad-enable ot-menu-iphone-enable"><div id="dat-menu" class="effect-1"><div class="dat-menu-container" style="background: url(&quot;https://www.tdlr.texas.gov/images/background-1.jpg&quot;) 0% 0% / auto repeat scroll padding-box border-box rgba(0, 0, 0, 0);"><div class="dat-menu-top-header"><a href="#dat-menu" class="dat-menu-menu"><i class="fa fa-bars"></i></a><a href="#" class="dat-menu-search"><i class="fa fa-search"></i></a><a href="#"><img src="/images/logo.png" style="background-color: #0589cd;" alt=""></a><form action=""><input type="text" name="s" value=""><input type="submit" value=""></form></div><div class="dat-menu-wrapper dat-menu-padding">\n    <!-- Google Tag Manager (noscript) -->\n    <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MPP5WF5" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>\n    <!-- End Google Tag Manager (noscript) -->\n\t<div class="boxed active">\n\t    <div class="devwrapper">\n\t\t\t<header class="header willfix">\n\t\t\t\t<div class="wrapper">\n\t\t\t\t\t<div class="header-left">\n\t\t\t\t\t\t<div class="header-logo">\n\t\t\t\t\t\t\t<a href="/index.htm" class="otanimation" data-anim-object=".header-logo a.otanimation img, .header-logo a.otanimation h1" data-anim-in="flipOutX" data-anim-out="bounceIn"><img src="/images/logo.png" alt=""></a>\n\t\t\t\t\t\t\t<strong data-anim-in="fadeOutUpBig" data-anim-out="bounceIn"><i class="fa fa-home"></i> Homepage</strong>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t\t<div class="header-socials">\n\t\t\t\t\t\t\t<a href="https://twitter.com/TDLRLicense"><i class="fa fa-twitter"></i></a>\n\t\t\t\t\t\t\t<a href="https://www.facebook.com/TDLRLicense"><i class="fa fa-facebook"></i></a>\n\t\t\t\t\t\t\t<a href="https://www.youtube.com/user/TexasLicensing/videos"><i class="fa fa-youtube"></i></a>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t</div>  <!-- end header-left -->\n\t\t\t\t\t<div class="header-right">\n\t\t\t\t\t\t<nav class="main-menu transition-active">\n\t\t\t\t\t\t\t<ul c ...

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for **cosmetologist violations** for people with the last name **Nguyen**.

# %%
driver.find_element_by_xpath("/html/body/div[1]/div/div[2]/div/div/section/div/div/table/tbody/tr/td/form/table/tbody/tr[3]/td/select/option[10]").click()

# %%
textbox = driver.find_element_by_xpath('//*[@id="pht_lnm"]')

# %%
textbox.send_keys("NGUYEN")

# %%
submit_button = driver.find_element_by_xpath('//*[@id="dat-menu"]/div/div[2]/div[1]/div/section/div/div/table/tbody/tr/td/form/table/tbody/tr[18]/td/input[1]')

# %%
submit_button.click()

# %% [markdown]
# ## Scraping
#
# Once you are on the results page, do this.

# %% [markdown]
# ### Loop through each result and print the entire row
#
# Okay wait, that's a heck of a lot. Use `[:10]` to only do the first ten (`listname[:10]` gives you the first ten).

# %%
import pandas as pd
# Out:
# /Users/sheridanwall/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
driver.page_source
# Out:
# '<html lang="en" class=" supports csstransforms3d"><head>\n\t\t<!-- Meta Tags -->\n\t\t<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n\t\t<!-- Favicon -->\n\t\t<link rel="shortcut icon" href="/images/favicon.png" type="image/x-icon">\n\t\t<!-- Stylesheets -->\n\t\t<link type="text/css" rel="stylesheet" href="/css/reset.css">\n\t\t<link type="text/css" rel="stylesheet" href="/css/font-awesome.min.css">\n\t\t<link type="text/css" rel="stylesheet" href="/css/animate.css">\n\t\t<link type="text/css" rel="stylesheet" href="/css/main-stylesheet.css">\n\t\t<link type="text/css" rel="stylesheet" href="/css/lightbox.css">\n\t\t<link type="text/css" rel="stylesheet" href="/css/shortcodes.css">\n\t\t<link type="text/css" rel="stylesheet" href="/css/custom-fonts.css">\n\t\t<link type="text/css" rel="stylesheet" href="/css/custom-colors.css">\n\t\t<link type="text/css" rel="stylesheet" href="/css/responsive.css">\n\t\t<link type="text/css" rel="stylesheet" href="/css/owl.carousel.css">\n\t\t<link type="text/css" rel="stylesheet" href="/css/owl.theme.css">\n\t\t<link type="text/css" rel="stylesheet" href="/css/dat-menu.css">\n\t\t\n\t\t<style>\n\t\t* {\n\t\tmargin: 0;\n\t\t}\n\t\thtml, body {\n\t\theight: 100%;\n\t\t}\n\t\tform {\n\t\t\theight:100%;\n\t\t}\n\t\t.devwrapper {\n\t\tmin-height: 100%;\n\t\theight: auto !important;\n\t\theight: 100%;\n\t\tmargin: 0 auto -140px;\n\t\t}\n\t\t.footer, .push {\n\t\theight: 140px;\n\t\t}\n\t\t\n\t\t@media print {\n\t\t\tbody {\n\t\t\t\tcolor: #000;\n\t\t\t\tbackground: #fff;\n\t\t\t\tmargin-left: none;\n\t\t\t\tpadding-left: none;\n\t\t\t}\n\n\t\t   .boxed.active {\n\t\t\t\twidth: 100%;\n\t\t\t\tmargin-left: none;\n\t\t\t\tpadding-left: none;\n\t\t\t}\n\t\t\t\n\t\t\t.header {\n\t\t\t\tdisplay: none;\n\t\t\t}\n\n\t\t\t.footer {\n\t\t\t\tdisplay: none;\n\t\t\t}\n\n\t\t</style>\n\t\t\n\t\t<!--[if lte IE 8]>\n\t\t<link type="text/css" rel="stylesheet" href="/css/ie-ancient.css" />\n\t\t<![endif]-->\n\n<!-- END head -->\n\n\t<title>Administrative Orders Search Results</title> \n\n    <!-- Google Tag Manager -->\n    <script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-MPP5WF5"></script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n    new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n    j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n    \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n    })(window,document,\'script\',\'dataLayer\',\'GTM-MPP5WF5\');</script>\n    <!-- End Google Tag Manager -->\n\t\n\t<link rel="stylesheet" type="text/css" href="css/fosearch.css">\n</head>\n\n<body class="ot-menu-ipad-enable ot-menu-iphone-enable"><div id="dat-menu" class="effect-1"><div class="dat-menu-container" style="background: url(&quot;https://www.tdlr.texas.gov/images/background-1.jpg&quot;) 0% 0% / auto repeat scroll padding-box border-box rgba(0, 0, 0, 0);"><div class="dat-menu-top-header"><a href="#dat-menu" class="dat-menu-menu"><i class="fa fa-bars"></i></a><a href="#" class="dat-menu-search"><i class="fa fa-search"></i></a><a href="#"><img src="/images/logo.png" style="background-color: #0589cd;" alt=""></a><form action=""><input type="text" name="s" value=""><input type="submit" value=""></form></div><div class="dat-menu-wrapper dat-menu-padding">\n    <!-- Google Tag Manager (noscript) -->\n    <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MPP5WF5"\n    height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>\n    <!-- End Google Tag Manager (noscript) -->\n\n<!-- TDLR_bodyheader.htm \n NOTE: target="_blank" is used in all links so that the web application\'s window remains unaffected when a link is clicked \n -->\n ...

# %%
tables = pd.read_html(driver.page_source)

# %%
nguyen = tables[0]

# %%
nguyen[:10]
# Out:
#                                    Name and Location  \
# 0  NGUYEN, MIMI PHAM City: KATY County: HARRIS Zi...
# 1  NGUYEN, HA City: ARLINGTON County: TARRANT Zip...
# 2  NGUYEN, THAO HONG City: SAN ANTONIO County: BE...
# 3  NGUYEN, CINDY City: CORPUS CHRISTI County: NUE...
# 4  NGUYEN, CHAU KHANH LINH City: MONTGOMERY Count...
# 5  NGUYEN, TRANG T City: SEGUIN County: GUADALUPE...
# 6  NGUYEN, DUNG MINH City: HOUSTON County: HARRIS...
# 7  NGUYEN, YEN NHI THI City: AUSTIN County: TRAVI...
# 8  NGUYEN, JOHNNY DAT City: MISSION County: HIDAL...
# 9  NGUYEN, KELLY PHUONG N City: CORPUS CHRISTI Co...
#
#                                                Order  \
# 0  Date: 11/12/2020Respondent is assessed an admi...
# 1  Date: 11/12/2020Respondent is assessed an admi...
# 2  Date: 11/12/2020Respondent is assessed an admi...
# 3  Date: 10/29/2020Respondent is assessed an admi...
# 4  Date: 10/26/2020The Respondent's Cosmetology M...
# 5  Date: 10/26/2020Respondent is assessed an admi...
# 6  Date: 10/19/2020Respondent is assessed an admi...
# 7  Date: 10/14/2020Respondent is assessed an admi...
# 8  Date: 10/14/2020Respondent is assessed an admi...
# 9  Date: 9/29/2020Respondent is assessed an admin...
#
#                                      Basis for Order
# 0  Respondent failed properly clean and sanitize ...
# 1  Respondent failed to clean and sanitize four (...
# 2  Respondent failed to clean, disinfect, and ste...
# 3  Respondent failed to clean and disinfect all w...
# 4  Respondent engaged in fraud or deceit in obtai...
# 5  Respondent failed properly clean and sanitize ...
# 6  Respondent failed properly clean and sanitize ...
# 7  Respondent failed to clean and disinfect all w...
# 8  Respondent failed to clean and sanitize whirlp...
# 9  Respondent failed properly clean and sanitize ...

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    # try to do something
# except:
#    # Instead of stopping on an error, it'll jump down here instead
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything, you can type `pass` instead of the `print` statement. Most people use `pass`, but it's also nice to print out debug statements so you know when/where it's running into errors.
#
# **Why doesn't the first one have a name?**

# %%
for names in tables:
    try:
        print(names['Name and Location'])
    except:
        pass
# Out:
# 0      NGUYEN, MIMI PHAM City: KATY County: HARRIS Zi...
# 1      NGUYEN, HA City: ARLINGTON County: TARRANT Zip...
# 2      NGUYEN, THAO HONG City: SAN ANTONIO County: BE...
# 3      NGUYEN, CINDY City: CORPUS CHRISTI County: NUE...
# 4      NGUYEN, CHAU KHANH LINH City: MONTGOMERY Count...
#                              ...
# 152    NGUYEN, SHARON City: BASTROP County: BASTROP Z...
# 153    NGUYEN, BINH THANH City: LAREDO County: WEBB Z...
# 154    NGUYEN, SAMANTHA TRAN City: MCKINNEY County: C...
# 155    NGUYEN, THU LE City: SAN ANTONIO County: BEXAR...
# 156    NGUYEN, KIM NGAN THI City: HOUSTON County: HAR...
# Name: Name and Location, Length: 157, dtype: object

# %%
names = driver.find_elements_by_tag_name("tr")
for name in names:
    try:
        full_name = name.find_elements_by_class_name("results_text")[0]
        print(full_name.text)
    except:
        print("None")

    
    
#     try:
#         print(names)
#     except:
#         pass
# Out:
# None
# NGUYEN, MIMI PHAM
# NGUYEN, HA
# NGUYEN, THAO HONG
# NGUYEN, CINDY
# NGUYEN, CHAU KHANH LINH
# NGUYEN, TRANG T
# NGUYEN, DUNG MINH
# NGUYEN, YEN NHI THI
# NGUYEN, JOHNNY DAT
# NGUYEN, KELLY PHUONG N
# NGUYEN, NGA THU
# NGUYEN, IVY
# NGUYEN, DIEMTRINH T
# NGUYEN, HUAN CAO
# NGUYEN, THOA KIM
# NGUYEN, TONY
# NGUYEN, HIEN
# NGUYEN, NGOC TRAM
# NGUYEN, TRAN NAM
# NGUYEN, PHILLIP
# NGUYEN, THUY T
# NGUYEN, TRACY
# NGUYEN, LE PHUC
# NGUYEN, HAI MINH
# NGUYEN, TUYET
# NGUYEN, BA VAN
# NGUYEN, LAN THANH
# NGUYEN, PHUOC BA
# NGUYEN, LINH THUY KIEU
# NGUYEN, TONY MINH
# NGUYEN, THANH
# NGUYEN, HIEN THI MINH
# NGUYEN, VAN NGOC THAO
# NGUYEN, TAM THANH
# NGUYEN, ANDY HUU
# NGUYEN, CUONG HULL
# NGUYEN, NANCY HOA
# NGUYEN, THOA THI KIM
# NGUYEN, TRANG
# NGUYEN, THONG VAN
# NGUYEN, TUAN
# NGUYEN, LYNDA
# NGUYEN, CATHY H
# NGUYEN, PAMELA DAN
# NGUYEN, SON QUOC
# NGUYEN, KIM
# NGUYEN, THAI VAN
# NGUYEN, HANH THI
# NGUYEN, DIEP THI NGOC
# NGUYEN, CASEY
# NGUYEN, ANTHONY VAN
# NGUYEN, CHRISTINA D
# NGUYEN, PHUONG T
# NGUYEN, KENNY
# NGUYEN, THAO (MINH THAO
# NGUYEN, KENNY
# NGUYEN, BA VAN
# NGUYEN, KHUYEN THI
# NGUYEN, SON DANG
# NGUYEN, TUYEN THANH
# NGUYEN, STEVEN THAI
# NGUYEN, CY VAN
# NGUYEN, QUANG DUC
# NGUYEN, OANH THI
# NGUYEN, AN QUY
# NGUYEN, HAU PHUC
# NGUYEN, KIM LIEN THI
# NGUYEN, KENNY KHANH
# NGUYEN, KIM LAN THI
# NGUYEN, DUONG VAN
# NGUYEN, HIEU CHAU
# NGUYEN, TRANG KIM
# NGUYEN, LINH H
# NGUYEN, PHUONG DUC
# NGUYEN, NGUYET M
# NGUYEN, VAN DO THI
# NGUYEN, XUAN THI
# NGUYEN, MICHAEL TAN
# NGUYEN, LANCHI
# NGUYEN, DIEM
# NGUYEN, LINH K
# NGUYEN, THOANG THI
# NGUYEN, HOAI THU T
# NGUYEN, JIMMY DUC
# NGUYEN, NINH VAN
# NGUYEN, THANH HUU
# NGUYEN, UYEN THI TU
# NGUYEN, BANH THI
# NGUYEN, KHIET THANH
# NGUYEN, SAM DUC
# NGUYEN, ANH HUU
# NGUYEN, DIANE N
# NGUYEN, MICHAEL
# NGUYEN, CUONG TRAN
# NGUYEN, TRAN NAM
# NGUYEN, TAMMY
# NGUYEN, SUONG THI TRUC
# NGUYEN, THE THI
# NGUYEN, KIMBERLY
# NGUYEN, DUY KINH
# NGUYEN, LEENA L
# NGUYEN, MAI TRANG
# NGUYEN, HUYEN T
# NGUYEN, TUNG T
# NGUYEN, HIEN XUAN T
# NGUYEN, TUYET
# NGUYEN, HUYEN THI-MINH
# NGUYEN, HOA VAN
# NGUYEN, PAUL
# NGUYEN, LOAN HONG ANH
# NGUYEN, MAI THI BACH
# NGUYEN, TUYET-MAI PHAM
# NGUYEN, LIEN THI B
# NGUYEN, MAI T
# NGUYEN, LIEN
# NGUYEN, NGOC THI
# NGUYEN, VIET LINH
# NGUYEN, COURTNEY
# NGUYEN, TUYEN T
# NGUYEN, NHON A
# NGUYEN, SOPHIE T
# NGUYEN, NGOC HONG THI
# NGUYEN, KHAN THI
# NGUYEN, ANNA AI
# NGUYEN, NHU MAI
# NGUYEN, DUNG QUANG
# NGUYEN, MINH THU
# NGUYEN, PHUONG THI
# NGUYEN, CHARLIE
# NGUYEN, HANH THI
# NGUYEN, MINH V
# NGUYEN, NHAN THANH
# NGUYEN, THUYET
# NGUYEN, QUANG XUAN
# NGUYEN, TRUNG N
# NGUYEN, MYCAM THI
# NGUYEN, THUYVI T
# NGUYEN, OANH PHUONG
# NGUYEN, QUANG Q
# NGUYEN, CINDY
# NGUYEN, KEVIN HOA
# NGUYEN, THUY T
# NGUYEN, THIENTRANG THI
# NGUYEN, MARY ANN
# NGUYEN, THANH CHUONG
# NGUYEN, PHUONG N
# NGUYEN, ANH TRAM
# NGUYEN, HIEN
# NGUYEN, TUAN A
# NGUYEN, LEON A
# NGUYEN, VINH QUANG
# NGUYEN, BINH VAN
# NGUYEN, SHARON
# NGUYEN, BINH THANH
# NGUYEN, SAMANTHA TRAN
# NGUYEN, THU LE
# NGUYEN, KIM NGAN THI

# %%
# for names in name:
#     print(names.find_element_by_class_name("results_text")[0]

# %%
# https://stackoverflow.com/questions/24795198/get-all-child-elements
# print(driver.find_elements_by_css_selector("*")[10].text)

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: You can get the HTML of something by doing `.get_attribute('innerHTML')` - it might help you diagnose your issue.*
# > - *Tip: Or I guess you could just skip the one with the problem...*

# %%
# for violation in tables:
#     try:
#         print(violation['Basis for Order'])
#     except:
#         pass

# %%
violations = driver.find_elements_by_tag_name("tr")
for violation in violations:
    try:
        order_basis = violation.find_elements_by_tag_name("td")[2]
        print(order_basis.text)
    except:
        pass
# Out:
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# Respondent failed to clean and sanitize four (4) whirlpool foot spas as required at the end of each day, constituting two (2) violations; Respondent failed to keep a record of the date and time of four (4) foot spas daily or bi-weekly cleaning and if the foot spas were not used, constituting two (2) violations.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to clean and disinfect all wax pots; Respondent failed to properly clean multi-use items prior to each service.
# Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to clean and disinfect all wax pots; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent stored chemicals in a restroom accessible to the public; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day - two violations.
# Respondent failed properly clean and sanitize the metal implements used at the Salon.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; After each client, the following implements shall be cleaned, disinfected and sterilized or sanitized in accordance with the rule: metal pusher and files, cuticle nipper and scissors, metal tweezers, finger and toe-nail clippers, and electric drill bits.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# Respondent failed to clean and disinfect all wax pots.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to cooperate with the inspector in the performance of an inspection.
# Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed properly clean and sanitize the metal implements used at the Salon.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.
# Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to maintain cleaning records for whirlpool foot spas; Respondent failed to utilize the sterilizer in the salon for the purpose of sterilizing metal implements; Respondent failed to store cosmetology items in a clean and debris free environment; Respondent stored chemical supplies in the restroom.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize all multi-use implements prior to each use.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# Respondent possessed or used a prohibited implement, specifically a blade or cutting tool intended for the purpose of removing corns or calluses.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to dispose of single use items after each use.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to make records, on a department-approved form with the date and time the salon discarded the liners for each whirlpool foot spas.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.
# Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent operated a cosmetology salon without the appropriate license.
# Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent stored chemicals in a restroom accessible to the public.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# Respondent was in possession of bottles containing methyl methacrylate monomer.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used constitutes two violations; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product. Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.
# On two (2) occasions, Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the manufacturer's instructions; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent performed or attempted to perform a practice of cosmetology with an expired license. Respondent operated a cosmetology salon without the appropriate license.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent employed a person as an operator who did not hold a license.
# Respondent failed to dispose of after each use all products and single use items that has been in contact with a client's skin.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# Respondent performed barbering without the required license.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer; Respondent failed to clean and disinfect all wax pots.
# Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent failed to cooperate with the inspector in the performance of an inspection.
# Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Respondent has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant after each client.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent operated a cosmetology salon without the appropriate license; Respondent performed or attempted to perform a practice of cosmetology without a license.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent failed to dispose of single use items after each use.
# Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area.
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent failed to properly disinfect implements at the end of each day.
# Respondent failed to clean and disinfect all wax pots; Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone.
# Respondent failed to clean and disinfect all wax pots.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent was in possession of bottles containing methyl methacrylate monomer.
# Respondent failed to clean and disinfect facial chairs and beds, including headrest, prior to providing service to each client; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day; Respondent failed to dispose of after each use all products and single use items that has been in contact with a client's skin.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the manufacturer's instructions; Respondent failed to clean and disinfect all wax pots.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to properly disinfect implements at the end of each day.
# Respondent failed to dispose of single use items after each use.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent was in possession of bottles containing methyl methacrylate monomer.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to ensure that only semi-permanent glue was used during eyelash extension services.
# Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant after each client.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.
# Respondent failed to dispose of single use items after each use.
# Respondent performed or attempted to perform a practice of cosmetology without a license.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Respondent has been convicted of a crime that was committed within 5 years of their renewal application; Respondent lacks sufficient honesty, trustworthiness and integrity to hold a license.
# Respondent was in possession of bottles containing methyl methacrylate monomer.
# Respondent was in possession of bottles containing methyl methacrylate monomer.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.
# Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.
# Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.
# Respondent failed to comply with an order previously issued by the Executive Director.
# Respondent interfered with a Department inspection of the salon.

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# - TIP: Think about the order of the elements

# %%
complaints = driver.find_elements_by_tag_name("tr")
for complaint in complaints:
    try:
        complaint_number = complaint.find_elements_by_class_name("results_text")[5]
        print(complaint_number.text)
    except:
        print("None")
# Out:
# None
# COS20190010072
# COS20190016762
# COS20200010387
# COS20200010502
# COS20190008104
# COS20200010511
# COS20200004202
# COS20190004199
# COS20200000101
# COS20200011664
# COS20200010961
# COS20200008858
# COS20200008859
# COS20200009732
# COS20200006548
# COS20200009605
# COS20190016479
# COS20190012148
# COS20190010318
# COS20190014688
# COS20190004016
# COS20190016499
# COS20200006146
# COS20190016549
# COS20190017217
# COS20190016854
# COS20190017175
# COS20190013017
# COS20190016161
# COS20200000652
# COS20190007906
# COS20190003737
# COS20190006118
# COS20200002642
# COS20190009211
# COS20190010611
# COS20190010665
# COS20190001932
# COS20190014576
# COS20190001897
# COS20190009239
# COS20190009484
# ROUND ROCK
# COS20190011923
# COS20190005539
# COS20190010176
# COS20190010397
# COS20190011044
# COS20190003373
# COS20190010299
# COS20190013988
# COS20190012652
# COS20180015395
# COS20190010057
# COS20190010254
# COS20190000183
# COS20190010606
# COS20190010961
# COS20190010635
# COS20190014566
# COS20190010869
# COS20190007921
# COS20180009800
# COS20180011968
# COS20180014900
# COS20190008675
# COS20190009912
# COS20190011097
# SAN ANGELO
# COS20180012023
# COS20190008542
# COS20190009430
# COS20190009953
# COS20190010248
# COS20190008693
# COS20180016583
# COS20190001467
# COS20190008543
# COS20190005139
# COS20190010629
# COS20190010964
# COS20190011791
# COS20190012199
# GRAND PRAIRIE
# COS20190003941
# COS20180004399
# COS20190001089
# COS20190007449
# COS20190002450
# COS20190005537
# PLANO
# COS20190001468
# COS20190003325
# COS20190006667
# COS20190005115
# COS20180011336
# COS20180002297
# COS20180015927
# COS20190000507
# COS20190001290
# COS20190002573
# COS20190003107
# COS20190005137
# COS20190005193
# COS20190002166
# COS20170022240
# COS20170016527
# COS20180003923
# COS20180016608
# COS20180016630
# COS20190001474
# COS20180008796
# COS20190005104
# COS20180013639
# COS20180014831
# COS20180016402
# COS20190001279
# COS20180016048
# COS20180016674
# COS20180016648
# COS20180015386
# COS20180016256
# COS20180003200
# COS20180011116
# COS20180016602
# COS20190001103
# COS20190001603
# COS20180015604
# COS20190000020
# COS20180014868
# COS20180010801
# COS20180011570
# COS20180009490
# COS20180014099
# COS20180007186
# COS20180011017
# COS20180014315
# COS20180015729
# COS20180012060
# COS20180014267
# COS20180012949
# COS20180014222
# COS20180010556
# COS20180014330
# COS20180007909
# COS20180008524
# COS20180011108
# COS20180013126
# COS20180008708
# COS20180008891
# COS20180012418
# COS20180015790
# COS20180013118
# COS20180012368
# COS20180006595
# COS20180007798
# COS2009004238D

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# > *Tip: If you want to ask for the "next sibling," you can't use `find_next_sibling` in Selenium, you need to use `element.find_element_by_xpath("following-sibling::div")` to find the next div, or `element.find_element_by_xpath("following-sibling::*")` to find the next anything.

# %%
items = driver.find_elements_by_tag_name("tr")

rows = []
for item in items:
    row = {}
    try:
        row['name'] = item.find_elements_by_class_name("results_text")[0].text
    except:
        pass
    try:
        row['violations'] = item.find_elements_by_tag_name("td")[2].text
    except:
        pass
    try:
        row['complaint'] = item.find_elements_by_class_name("results_text")[5].text
    except:
        pass
    try:
        row['license'] = item.find_elements_by_class_name("results_text")[4].text
    except:
        pass
    try:
        row['zipcode'] = item.find_elements_by_class_name("results_text")[3].text
    except:
        pass
    try:
        row['county'] = item.find_elements_by_class_name("results_text")[2].text
    except:
        pass
    try:
        row['city'] = item.find_elements_by_class_name("results_text")[1].text
    except:
        pass
    print(row)
    rows.append(row)
    print('--------')
# Out:
# {}
# --------
# {'name': 'NGUYEN, MIMI PHAM', 'violations': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.', 'complaint': 'COS20190010072', 'license': '784210', 'zipcode': '77449', 'county': 'HARRIS', 'city': 'KATY'}
# --------
# {'name': 'NGUYEN, HA', 'violations': 'Respondent failed to clean and sanitize four (4) whirlpool foot spas as required at the end of each day, constituting two (2) violations; Respondent failed to keep a record of the date and time of four (4) foot spas daily or bi-weekly cleaning and if the foot spas were not used, constituting two (2) violations.', 'complaint': 'COS20190016762', 'license': '764888', 'zipcode': '76017', 'county': 'TARRANT', 'city': 'ARLINGTON'}
# --------
# {'name': 'NGUYEN, THAO HONG', 'violations': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.', 'complaint': 'COS20200010387', 'license': '799926, 1753491', 'zipcode': '78238', 'county': 'BEXAR', 'city': 'SAN ANTONIO'}
# --------
# {'name': 'NGUYEN, CINDY', 'violations': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to properly clean multi-use items prior to each service.', 'complaint': 'COS20200010502', 'license': '806232, 1260359, 1280071', 'zipcode': '78414', 'county': 'NUECES', 'city': 'CORPUS CHRISTI'}
# --------
# {'name': 'NGUYEN, CHAU KHANH LINH', 'violations': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.', 'complaint': 'COS20190008104', 'license': '1764073', 'zipcode': '36116', 'county': 'OUT OF STATE', 'city': 'MONTGOMERY'}
# --------
# {'name': 'NGUYEN, TRANG T', 'violations': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to wipe clean and disinfect electrical equipment that cannot be immersed in the liquid prior to each use on a client.', 'complaint': 'COS20200010511', 'license': '748483', 'zipcode': '78155', 'county': 'GUADALUPE', 'city': 'SEGUIN'}
# --------
# {'name': 'NGUYEN, DUNG MINH', 'violations': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to store eyelash extensions in a sealed bag or covered container and kept in a clean dry debris-free storage area; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.', 'complaint': 'COS20200004202', 'license': '785878', 'zipcode': '77066', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, YEN NHI THI', 'violations': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondent stored chemicals in a restroom accessible to the public; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.', 'complaint': 'COS20190004199', 'license': '763645', 'zipcode': '78717', 'county': 'TRAVIS', 'city': 'AUSTIN'}
# --------
# {'name': 'NGUYEN, JOHNNY DAT', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day - two violations.', 'complaint': 'COS20200000101', 'license': '797651', 'zipcode': '78574', 'county': 'HIDALGO', 'city': 'MISSION'}
# --------
# {'name': 'NGUYEN, KELLY PHUONG N', 'violations': 'Respondent failed properly clean and sanitize the metal implements used at the Salon.', 'complaint': 'COS20200011664', 'license': '751553', 'zipcode': '78413', 'county': 'NUECES', 'city': 'CORPUS CHRISTI'}
# --------
# {'name': 'NGUYEN, NGA THU', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.', 'complaint': 'COS20200010961', 'license': '737176', 'zipcode': '77038', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, IVY', 'violations': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.', 'complaint': 'COS20200008858', 'license': '772886', 'zipcode': '75092', 'county': 'GRAYSON', 'city': 'SHERMAN'}
# --------
# {'name': 'NGUYEN, DIEMTRINH T', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.', 'complaint': 'COS20200008859', 'license': '736591', 'zipcode': '75010', 'county': 'DALLAS', 'city': 'CARROLLTON'}
# --------
# {'name': 'NGUYEN, HUAN CAO', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; After each client, the following implements shall be cleaned, disinfected and sterilized or sanitized in accordance with the rule: metal pusher and files, cuticle nipper and scissors, metal tweezers, finger and toe-nail clippers, and electric drill bits.', 'complaint': 'COS20200009732', 'license': '786237', 'zipcode': '78229', 'county': 'BEXAR', 'city': 'SAN ANTONIO'}
# --------
# {'name': 'NGUYEN, THOA KIM', 'violations': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.', 'complaint': 'COS20200006548', 'license': '758361', 'zipcode': '78413', 'county': 'NUECES', 'city': 'CORPUS CHRISTI'}
# --------
# {'name': 'NGUYEN, TONY', 'violations': 'Respondent performed or attempted to perform a practice of cosmetology without a license.', 'complaint': 'COS20200009605', 'license': 'Not Licensed', 'zipcode': '78654', 'county': 'BURNET', 'city': 'MARBLE FALLS'}
# --------
# {'name': 'NGUYEN, HIEN', 'violations': 'Respondent failed to clean and disinfect all wax pots.', 'complaint': 'COS20190016479', 'license': '801727', 'zipcode': '75605', 'county': 'GREGG', 'city': 'LONGVIEW'}
# --------
# {'name': 'NGUYEN, NGOC TRAM', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190012148', 'license': '712767', 'zipcode': '76137', 'county': 'TARRANT', 'city': 'FORT WORTH'}
# --------
# {'name': 'NGUYEN, TRAN NAM', 'violations': 'Respondent failed to cooperate with the inspector in the performance of an inspection.', 'complaint': 'COS20190010318', 'license': '733729', 'zipcode': '79015', 'county': 'RANDALL', 'city': 'CANYON'}
# --------
# {'name': 'NGUYEN, PHILLIP', 'violations': 'Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day.', 'complaint': 'COS20190014688', 'license': '692372', 'zipcode': '79912', 'county': 'EL PASO', 'city': 'EL PASO'}
# --------
# {'name': 'NGUYEN, THUY T', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed properly clean and sanitize the metal implements used at the Salon.', 'complaint': 'COS20190004016', 'license': '794091', 'zipcode': '75007', 'county': 'DALLAS', 'city': 'CARROLLTON'}
# --------
# {'name': 'NGUYEN, TRACY', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.', 'complaint': 'COS20190016499', 'license': '746762', 'zipcode': '76137', 'county': 'TARRANT', 'city': 'FORT WORTH'}
# --------
# {'name': 'NGUYEN, LE PHUC', 'violations': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20200006146', 'license': '739879', 'zipcode': '75048', 'county': 'COLLIN', 'city': 'SACHSE'}
# --------
# {'name': 'NGUYEN, HAI MINH', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.', 'complaint': 'COS20190016549', 'license': '726039, 1110890', 'zipcode': '79936', 'county': 'EL PASO', 'city': 'EL PASO'}
# --------
# {'name': 'NGUYEN, TUYET', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190017217', 'license': '774330, 1658860', 'zipcode': '75052', 'county': 'DALLAS', 'city': 'GRAND PRAIRIE'}
# --------
# {'name': 'NGUYEN, BA VAN', 'violations': 'Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.', 'complaint': 'COS20190016854', 'license': '676940', 'zipcode': '76001', 'county': 'TARRANT', 'city': 'ARLINGTON'}
# --------
# {'name': 'NGUYEN, LAN THANH', 'violations': 'Respondent failed properly clean and sanitize the metal implements used at the Salon; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.', 'complaint': 'COS20190017175', 'license': '766697', 'zipcode': '75216', 'county': 'DALLAS', 'city': 'DALLAS'}
# --------
# {'name': 'NGUYEN, PHUOC BA', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190013017', 'license': '788725, 1552617', 'zipcode': '78250', 'county': 'BEXAR', 'city': 'SAN ANTONIO'}
# --------
# {'name': 'NGUYEN, LINH THUY KIEU', 'violations': 'Respondent failed to follow proper sequential cleaning and disinfecting procedures when using portable whirlpool jets.', 'complaint': 'COS20190016161', 'license': '795480, 1700076', 'zipcode': '75044', 'county': 'DALLAS', 'city': 'GARLAND'}
# --------
# {'name': 'NGUYEN, TONY MINH', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20200000652', 'license': '791638, 1124706', 'zipcode': '78654', 'county': 'BURNET', 'city': 'MARBLE FALLS'}
# --------
# {'name': 'NGUYEN, THANH', 'violations': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.', 'complaint': 'COS20190007906', 'license': '790672', 'zipcode': '75034', 'county': 'COLLIN', 'city': 'FRISCO'}
# --------
# {'name': 'NGUYEN, HIEN THI MINH', 'violations': 'Respondent failed to maintain cleaning records for whirlpool foot spas; Respondent failed to utilize the sterilizer in the salon for the purpose of sterilizing metal implements; Respondent failed to store cosmetology items in a clean and debris free environment; Respondent stored chemical supplies in the restroom.', 'complaint': 'COS20190003737', 'license': '795179', 'zipcode': '77083', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, VAN NGOC THAO', 'violations': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean, disinfect, and sterilize all multi-use implements prior to each use.', 'complaint': 'COS20190006118', 'license': 'Not Licensed', 'zipcode': '75165', 'county': 'ELLIS', 'city': 'WAXAHACHIE'}
# --------
# {'name': 'NGUYEN, TAM THANH', 'violations': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.", 'complaint': 'COS20200002642', 'license': '1163702', 'zipcode': '76904', 'county': 'TOM GREEN', 'city': 'SAN ANGELO'}
# --------
# {'name': 'NGUYEN, ANDY HUU', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.', 'complaint': 'COS20190009211', 'license': '776906, 1189873', 'zipcode': '76053', 'county': 'TARRANT', 'city': 'HURST'}
# --------
# {'name': 'NGUYEN, CUONG HULL', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190010611', 'license': '767705, 1094245', 'zipcode': '75052', 'county': 'TARRANT', 'city': 'GRAND PRAIRIE'}
# --------
# {'name': 'NGUYEN, NANCY HOA', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.', 'complaint': 'COS20190010665', 'license': '785647, 1121812', 'zipcode': '75044', 'county': 'DALLAS', 'city': 'GARLAND'}
# --------
# {'name': 'NGUYEN, THOA THI KIM', 'violations': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.', 'complaint': 'COS20190001932', 'license': '739510', 'zipcode': '78411', 'county': 'NUECES', 'city': 'CORPUS CHRISTI'}
# --------
# {'name': 'NGUYEN, TRANG', 'violations': 'Respondent possessed or used a prohibited implement, specifically a blade or cutting tool intended for the purpose of removing corns or calluses.', 'complaint': 'COS20190014576', 'license': '693311', 'zipcode': '75041', 'county': 'DALLAS', 'city': 'GARLAND'}
# --------
# {'name': 'NGUYEN, THONG VAN', 'violations': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.', 'complaint': 'COS20190001897', 'license': '750663', 'zipcode': '79912', 'county': 'EL PASO', 'city': 'EL PASO'}
# --------
# {'name': 'NGUYEN, TUAN', 'violations': "Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant.", 'complaint': 'COS20190009239', 'license': '783281', 'zipcode': '75237', 'county': 'DALLAS', 'city': 'DALLAS'}
# --------
# {'name': 'NGUYEN, LYNDA', 'violations': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to dispose of single use items after each use.', 'complaint': 'COS20190009484', 'license': '781789', 'zipcode': '77449', 'county': 'HARRIS', 'city': 'KATY'}
# --------
# {'name': 'NGUYEN, CATHY H', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'ROUND ROCK', 'license': 'NGUYEN, JOHNNY VAN', 'zipcode': '78665', 'county': 'WILLIAMSON', 'city': 'ROUND ROCK'}
# --------
# {'name': 'NGUYEN, PAMELA DAN', 'violations': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to make records, on a department-approved form with the date and time the salon discarded the liners for each whirlpool foot spas.', 'complaint': 'COS20190011923', 'license': '747589', 'zipcode': '78155', 'county': 'GUADALUPE', 'city': 'SEGUIN'}
# --------
# {'name': 'NGUYEN, SON QUOC', 'violations': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.', 'complaint': 'COS20190005539', 'license': '772305, 1240974', 'zipcode': '76645', 'county': 'HILL', 'city': 'HILLSBORO'}
# --------
# {'name': 'NGUYEN, KIM', 'violations': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.', 'complaint': 'COS20190010176', 'license': '786602', 'zipcode': '75240', 'county': 'DALLAS', 'city': 'DALLAS'}
# --------
# {'name': 'NGUYEN, THAI VAN', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.', 'complaint': 'COS20190010397', 'license': '797287, 1187211', 'zipcode': '75040', 'county': 'DALLAS', 'city': 'GARLAND'}
# --------
# {'name': 'NGUYEN, HANH THI', 'violations': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.', 'complaint': 'COS20190011044', 'license': '786707', 'zipcode': '77049', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, DIEP THI NGOC', 'violations': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.', 'complaint': 'COS20190003373', 'license': '760528', 'zipcode': '77067', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, CASEY', 'violations': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.', 'complaint': 'COS20190010299', 'license': '790137', 'zipcode': '77429', 'county': 'HARRIS', 'city': 'CYPRESS'}
# --------
# {'name': 'NGUYEN, ANTHONY VAN', 'violations': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.", 'complaint': 'COS20190013988', 'license': '750159', 'zipcode': '76117', 'county': 'TARRANT', 'city': 'HALTOM CITY'}
# --------
# {'name': 'NGUYEN, CHRISTINA D', 'violations': 'Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190012652', 'license': '716740', 'zipcode': '77642', 'county': 'JEFFERSON', 'city': 'PORT ARTHUR'}
# --------
# {'name': 'NGUYEN, PHUONG T', 'violations': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.', 'complaint': 'COS20180015395', 'license': '748459', 'zipcode': '77083', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, KENNY', 'violations': 'Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.', 'complaint': 'COS20190010057', 'license': '75611', 'zipcode': '75232', 'county': 'DALLAS', 'city': 'DALLAS'}
# --------
# {'name': 'NGUYEN, THAO (MINH THAO', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.', 'complaint': 'COS20190010254', 'license': '785264', 'zipcode': '78644', 'county': 'CALDWELL', 'city': 'LOCKHART'}
# --------
# {'name': 'NGUYEN, KENNY', 'violations': 'Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.', 'complaint': 'COS20190000183', 'license': '756711', 'zipcode': '75232', 'county': 'DALLAS', 'city': 'DALLAS'}
# --------
# {'name': 'NGUYEN, BA VAN', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190010606', 'license': '720112', 'zipcode': '76063', 'county': 'TARRANT', 'city': 'MANSFIELD'}
# --------
# {'name': 'NGUYEN, KHUYEN THI', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190010961', 'license': '771681, 1442799', 'zipcode': '76117', 'county': 'TARRANT', 'city': 'HALTOM CITY'}
# --------
# {'name': 'NGUYEN, SON DANG', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190010635', 'license': '720091, 1195752', 'zipcode': '76119', 'county': 'TARRANT', 'city': 'FOREST HILL'}
# --------
# {'name': 'NGUYEN, TUYEN THANH', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.', 'complaint': 'COS20190014566', 'license': '792178, 1468619, 1410422', 'zipcode': '76227', 'county': 'DENTON', 'city': 'AUBREY'}
# --------
# {'name': 'NGUYEN, STEVEN THAI', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190010869', 'license': '779635', 'zipcode': '75007', 'county': 'DALLAS', 'city': 'CARROLLTON'}
# --------
# {'name': 'NGUYEN, CY VAN', 'violations': 'Respondent operated a cosmetology salon without the appropriate license.', 'complaint': 'COS20190007921', 'license': '765590', 'zipcode': '77007', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, QUANG DUC', 'violations': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent stored chemicals in a restroom accessible to the public.', 'complaint': 'COS20180009800', 'license': '749600, 1225146', 'zipcode': '79424', 'county': 'LUBBOCK', 'city': 'LUBBOCK'}
# --------
# {'name': 'NGUYEN, OANH THI', 'violations': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required when using portable whirlpool jets; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.', 'complaint': 'COS20180011968', 'license': '770502', 'zipcode': '77351', 'county': 'POLK', 'city': 'LIVINGSTON'}
# --------
# {'name': 'NGUYEN, AN QUY', 'violations': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.', 'complaint': 'COS20180014900', 'license': '751433, 1083641', 'zipcode': '78249', 'county': 'BEXAR', 'city': 'SAN ANTONIO'}
# --------
# {'name': 'NGUYEN, HAU PHUC', 'violations': 'Respondent was in possession of bottles containing methyl methacrylate monomer.', 'complaint': 'COS20190008675', 'license': '744770', 'zipcode': '78414', 'county': 'NUECES', 'city': 'CORPUS CHRISTI'}
# --------
# {'name': 'NGUYEN, KIM LIEN THI', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.', 'complaint': 'COS20190009912', 'license': '713587', 'zipcode': '79107', 'county': 'POTTER', 'city': 'AMARILLO'}
# --------
# {'name': 'NGUYEN, KENNY KHANH', 'violations': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.", 'complaint': 'COS20190011097', 'license': '745308, 1419838', 'zipcode': '78641', 'county': 'WILLIAMSON', 'city': 'LEANDER'}
# --------
# {'name': 'NGUYEN, KIM LAN THI', 'violations': "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used constitutes two violations; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.", 'complaint': 'SAN ANGELO', 'license': 'NGUYEN, THUY TRANG T', 'zipcode': '76901', 'county': 'TOM GREEN', 'city': 'SAN ANGELO'}
# --------
# {'name': 'NGUYEN, DUONG VAN', 'violations': 'Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product. Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.', 'complaint': 'COS20180012023', 'license': '748281', 'zipcode': '75110', 'county': 'NAVARRO', 'city': 'CORSICANA'}
# --------
# {'name': 'NGUYEN, HIEU CHAU', 'violations': 'On two (2) occasions, Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day. Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.', 'complaint': 'COS20190008542', 'license': '777856', 'zipcode': '79938', 'county': 'EL PASO', 'city': 'EL PASO'}
# --------
# {'name': 'NGUYEN, TRANG KIM', 'violations': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190009430', 'license': '773798', 'zipcode': '77357', 'county': 'MONTGOMERY', 'city': 'NEW CANEY'}
# --------
# {'name': 'NGUYEN, LINH H', 'violations': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.', 'complaint': 'COS20190009953', 'license': '78841, 1520821', 'zipcode': '78109', 'county': 'BEXAR', 'city': 'CONVERSE'}
# --------
# {'name': 'NGUYEN, PHUONG DUC', 'violations': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the manufacturer's instructions; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.", 'complaint': 'COS20190010248', 'license': '746023, 1244227, 1549650', 'zipcode': '79772', 'county': 'REEVES', 'city': 'PECOS'}
# --------
# {'name': 'NGUYEN, NGUYET M', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190008693', 'license': '724763, 1327682, 1148025', 'zipcode': '76116', 'county': 'TARRANT', 'city': 'FORT WORTH'}
# --------
# {'name': 'NGUYEN, VAN DO THI', 'violations': 'Respondent performed or attempted to perform a practice of cosmetology with an expired license. Respondent operated a cosmetology salon without the appropriate license.', 'complaint': 'COS20180016583', 'license': '749933, 1695846', 'zipcode': '75002', 'county': 'COLLIN', 'city': 'ALLEN'}
# --------
# {'name': 'NGUYEN, XUAN THI', 'violations': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.', 'complaint': 'COS20190001467', 'license': '765777', 'zipcode': '77066', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, MICHAEL TAN', 'violations': 'Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.', 'complaint': 'COS20190008543', 'license': '751319, 1654218', 'zipcode': '78382', 'county': 'ARANSAS', 'city': 'ROCKPORT'}
# --------
# {'name': 'NGUYEN, LANCHI', 'violations': 'Respondent performed or attempted to perform a practice of cosmetology without a license.', 'complaint': 'COS20190005139', 'license': 'Not Licensed', 'zipcode': '77015', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, DIEM', 'violations': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.', 'complaint': 'COS20190010629', 'license': '688282', 'zipcode': '75080', 'county': 'DALLAS', 'city': 'RICHARDSON'}
# --------
# {'name': 'NGUYEN, LINH K', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190010964', 'license': '678261, 871430', 'zipcode': '77072', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, THOANG THI', 'violations': 'Respondent employed a person as an operator who did not hold a license.', 'complaint': 'COS20190011791', 'license': '775443', 'zipcode': '77075', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, HOAI THU T', 'violations': "Respondent failed to dispose of after each use all products and single use items that has been in contact with a client's skin.", 'complaint': 'COS20190012199', 'license': '735244', 'zipcode': '79925', 'county': 'EL PASO', 'city': 'EL PASO'}
# --------
# {'name': 'NGUYEN, JIMMY DUC', 'violations': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron.', 'complaint': 'GRAND PRAIRIE', 'license': 'NGUYEN, MONG', 'zipcode': '76051', 'county': 'TARRANT', 'city': 'GRAPEVINE'}
# --------
# {'name': 'NGUYEN, NINH VAN', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190003941', 'license': '666588', 'zipcode': '75052', 'county': 'TARRANT', 'city': 'GRAND PRAIRIE'}
# --------
# {'name': 'NGUYEN, THANH HUU', 'violations': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.', 'complaint': 'COS20180004399', 'license': '745484, 1259159', 'zipcode': '75081', 'county': 'DALLAS', 'city': 'RICHARDSON'}
# --------
# {'name': 'NGUYEN, UYEN THI TU', 'violations': 'Respondent performed or attempted to perform a practice of cosmetology without a license.', 'complaint': 'COS20190001089', 'license': 'Not Licensed', 'zipcode': '75904', 'county': 'ANGELINA', 'city': 'LUFKIN'}
# --------
# {'name': 'NGUYEN, BANH THI', 'violations': 'Respondent performed barbering without the required license.', 'complaint': 'COS20190007449', 'license': 'Not Licensed', 'zipcode': '71854', 'county': 'OUT OF STATE', 'city': 'TEXARKANA'}
# --------
# {'name': 'NGUYEN, KHIET THANH', 'violations': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.', 'complaint': 'COS20190002450', 'license': '710894', 'zipcode': '78413', 'county': 'NUECES', 'city': 'CORPUS CHRISTI'}
# --------
# {'name': 'NGUYEN, SAM DUC', 'violations': 'Respondent failed to dispose of single use items after each use; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.', 'complaint': 'COS20190005537', 'license': '772341, 1596452', 'zipcode': '78840', 'county': 'VAL VERDE', 'city': 'DEL RIO'}
# --------
# {'name': 'NGUYEN, ANH HUU', 'violations': 'Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer; Respondent failed to clean and disinfect all wax pots.', 'complaint': 'PLANO', 'license': 'NGUYEN, YEN HONG', 'zipcode': '75094', 'county': 'COLLIN', 'city': 'PLANO'}
# --------
# {'name': 'NGUYEN, DIANE N', 'violations': 'Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.', 'complaint': 'COS20190001468', 'license': '681377, 1135046', 'zipcode': '76904', 'county': 'TOM GREEN', 'city': 'SAN ANGELO'}
# --------
# {'name': 'NGUYEN, MICHAEL', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190003325', 'license': '737006, 1155545', 'zipcode': '76014', 'county': 'TARRANT', 'city': 'ARLINGTON'}
# --------
# {'name': 'NGUYEN, CUONG TRAN', 'violations': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.", 'complaint': 'COS20190006667', 'license': '1594001', 'zipcode': '76137', 'county': 'TARRANT', 'city': 'FORT WORTH'}
# --------
# {'name': 'NGUYEN, TRAN NAM', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.', 'complaint': 'COS20190005115', 'license': '690490, 1143200', 'zipcode': '79015', 'county': 'RANDALL', 'city': 'CANYON'}
# --------
# {'name': 'NGUYEN, TAMMY', 'violations': 'Respondent failed to cooperate with the inspector in the performance of an inspection.', 'complaint': 'COS20180011336', 'license': '781568, 1712086, 1234366, 1487516', 'zipcode': '79606', 'county': 'TAYLOR', 'city': 'ABILENE'}
# --------
# {'name': 'NGUYEN, SUONG THI TRUC', 'violations': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.', 'complaint': 'COS20180002297', 'license': '1695256', 'zipcode': '74048', 'county': 'COLLIN', 'city': 'SACHSE'}
# --------
# {'name': 'NGUYEN, THE THI', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.', 'complaint': 'COS20180015927', 'license': '728111, 1097604, 1437455', 'zipcode': '79336', 'county': 'HOCKLEY', 'city': 'LEVELLAND'}
# --------
# {'name': 'NGUYEN, KIMBERLY', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.', 'complaint': 'COS20190000507', 'license': '785284, 1516790', 'zipcode': '75604', 'county': 'GREGG', 'city': 'LONGVIEW'}
# --------
# {'name': 'NGUYEN, DUY KINH', 'violations': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.', 'complaint': 'COS20190001290', 'license': '765758, 1594533', 'zipcode': '78613', 'county': 'WILLIAMSON', 'city': 'CEDAR PARK'}
# --------
# {'name': 'NGUYEN, LEENA L', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190002573', 'license': '793631', 'zipcode': '79924', 'county': 'EL PASO', 'city': 'EL PASO'}
# --------
# {'name': 'NGUYEN, MAI TRANG', 'violations': 'Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.', 'complaint': 'COS20190003107', 'license': '792260, 1749538', 'zipcode': '75056', 'county': 'DENTON', 'city': 'THE COLONY'}
# --------
# {'name': 'NGUYEN, HUYEN T', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.', 'complaint': 'COS20190005137', 'license': '774449, 1152042', 'zipcode': '77015', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, TUNG T', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.', 'complaint': 'COS20190005193', 'license': '785431, 1667712', 'zipcode': '75703', 'county': 'SMITH', 'city': 'TYLER'}
# --------
# {'name': 'NGUYEN, HIEN XUAN T', 'violations': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190002166', 'license': '741087', 'zipcode': '78248', 'county': 'BEXAR', 'city': 'SAN ANTONIO'}
# --------
# {'name': 'NGUYEN, TUYET', 'violations': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.', 'complaint': 'COS20170022240', 'license': '774330', 'zipcode': '75052', 'county': 'DALLAS', 'city': 'GRAND PRAIRIE'}
# --------
# {'name': 'NGUYEN, HUYEN THI-MINH', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20170016527', 'license': '732356, 1440217, 1529693', 'zipcode': '78727', 'county': 'TRAVIS', 'city': 'AUSTIN'}
# --------
# {'name': 'NGUYEN, HOA VAN', 'violations': "Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Respondent has been convicted of an offense that directly relates to the duties and responsibilities of the licensed occupation.", 'complaint': 'COS20180003923', 'license': '1216926', 'zipcode': '78753', 'county': 'TRAVIS', 'city': 'AUSTIN'}
# --------
# {'name': 'NGUYEN, PAUL', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.', 'complaint': 'COS20180016608', 'license': '774054', 'zipcode': '75070', 'county': 'COLLIN', 'city': 'MCKINNEY'}
# --------
# {'name': 'NGUYEN, LOAN HONG ANH', 'violations': "Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant after each client.", 'complaint': 'COS20180016630', 'license': '757086', 'zipcode': '76002', 'county': 'TARRANT', 'city': 'ARLINGTON'}
# --------
# {'name': 'NGUYEN, MAI THI BACH', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190001474', 'license': '725831', 'zipcode': '75172', 'county': 'DALLAS', 'city': 'WILMER'}
# --------
# {'name': 'NGUYEN, TUYET-MAI PHAM', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20180008796', 'license': '786753', 'zipcode': '75044', 'county': 'DALLAS', 'city': 'GARLAND'}
# --------
# {'name': 'NGUYEN, LIEN THI B', 'violations': 'Respondent operated a cosmetology salon without the appropriate license; Respondent performed or attempted to perform a practice of cosmetology without a license.', 'complaint': 'COS20190005104', 'license': '794022', 'zipcode': '75601', 'county': 'GREGG', 'city': 'LONGVIEW'}
# --------
# {'name': 'NGUYEN, MAI T', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.', 'complaint': 'COS20180013639', 'license': '750076', 'zipcode': '78735', 'county': 'TRAVIS', 'city': 'AUSTIN'}
# --------
# {'name': 'NGUYEN, LIEN', 'violations': 'Respondent failed to dispose of single use items after each use.', 'complaint': 'COS20180014831', 'license': '746980', 'zipcode': '79109', 'county': 'POTTER', 'city': 'AMARILLO'}
# --------
# {'name': 'NGUYEN, NGOC THI', 'violations': 'Respondent failed to properly ventilate the salon to eliminate strong odors away from the public area.', 'complaint': 'COS20180016402', 'license': '737411, 1669514, 1140000, 1240416, 1562212', 'zipcode': '77072', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, VIET LINH', 'violations': 'Respondent performed or attempted to perform a practice of cosmetology without a license.', 'complaint': 'COS20190001279', 'license': 'Not Licensed', 'zipcode': '75092', 'county': 'GRAYSON', 'city': 'SHERMAN'}
# --------
# {'name': 'NGUYEN, COURTNEY', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20180016048', 'license': '745292', 'zipcode': '75757', 'county': 'SMITH', 'city': 'BULLARD'}
# --------
# {'name': 'NGUYEN, TUYEN T', 'violations': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer.', 'complaint': 'COS20180016674', 'license': '790119, 767335, 1680828', 'zipcode': '77086', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, NHON A', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20180016648', 'license': '734240', 'zipcode': '79745', 'county': 'WINKLER', 'city': 'KERMIT'}
# --------
# {'name': 'NGUYEN, SOPHIE T', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.', 'complaint': 'COS20180015386', 'license': '774072', 'zipcode': '79912', 'county': 'EL PASO', 'city': 'EL PASO'}
# --------
# {'name': 'NGUYEN, NGOC HONG THI', 'violations': 'Respondent failed to properly disinfect implements at the end of each day.', 'complaint': 'COS20180016256', 'license': '725673', 'zipcode': '77090', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, KHAN THI', 'violations': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone.', 'complaint': 'COS20180003200', 'license': '778045, 1290177', 'zipcode': '77833', 'county': 'WASHINGTON', 'city': 'BRENHAM'}
# --------
# {'name': 'NGUYEN, ANNA AI', 'violations': 'Respondent failed to clean and disinfect all wax pots.', 'complaint': 'COS20180011116', 'license': '776928, 1475816', 'zipcode': '75024', 'county': 'COLLIN', 'city': 'PLANO'}
# --------
# {'name': 'NGUYEN, NHU MAI', 'violations': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.', 'complaint': 'COS20180016602', 'license': '745586', 'zipcode': '75024', 'county': 'COLLIN', 'city': 'PLANO'}
# --------
# {'name': 'NGUYEN, DUNG QUANG', 'violations': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20190001103', 'license': '749917, 1165768', 'zipcode': '75206', 'county': 'DALLAS', 'city': 'DALLAS'}
# --------
# {'name': 'NGUYEN, MINH THU', 'violations': 'Respondent was in possession of bottles containing methyl methacrylate monomer.', 'complaint': 'COS20190001603', 'license': '790174', 'zipcode': '79934', 'county': 'EL PASO', 'city': 'EL PASO'}
# --------
# {'name': 'NGUYEN, PHUONG THI', 'violations': "Respondent failed to clean and disinfect facial chairs and beds, including headrest, prior to providing service to each client; Respondent failed to sweep up and deposit hair cuttings in a closed receptacle after each hair cut. Respondent failed to thoroughly clean the floors each day; Respondent failed to dispose of after each use all products and single use items that has been in contact with a client's skin.", 'complaint': 'COS20180015604', 'license': '772550', 'zipcode': '77478', 'county': 'FORT BEND', 'city': 'SUGAR LAND'}
# --------
# {'name': 'NGUYEN, CHARLIE', 'violations': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the manufacturer's instructions; Respondent failed to clean and disinfect all wax pots.", 'complaint': 'COS20190000020', 'license': '763659', 'zipcode': '75219', 'county': 'DALLAS', 'city': 'DALLAS'}
# --------
# {'name': 'NGUYEN, HANH THI', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20180014868', 'license': '761658', 'zipcode': '75237', 'county': 'DALLAS', 'city': 'DALLAS'}
# --------
# {'name': 'NGUYEN, MINH V', 'violations': 'Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.', 'complaint': 'COS20180010801', 'license': '745051', 'zipcode': '79928', 'county': 'EL PASO', 'city': 'HORIZON CITY'}
# --------
# {'name': 'NGUYEN, NHAN THANH', 'violations': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.", 'complaint': 'COS20180011570', 'license': '1265637', 'zipcode': '75040', 'county': 'DALLAS', 'city': 'GARLAND'}
# --------
# {'name': 'NGUYEN, THUYET', 'violations': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.', 'complaint': 'COS20180009490', 'license': '720045', 'zipcode': '78251', 'county': 'BEXAR', 'city': 'SAN ANTONIO'}
# --------
# {'name': 'NGUYEN, QUANG XUAN', 'violations': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to properly disinfect implements at the end of each day.', 'complaint': 'COS20180014099', 'license': '738063, 1231599', 'zipcode': '75180', 'county': 'DALLAS', 'city': 'BALCH SPRINGS'}
# --------
# {'name': 'NGUYEN, TRUNG N', 'violations': 'Respondent failed to dispose of single use items after each use.', 'complaint': 'COS20180007186', 'license': '767014, 1196244', 'zipcode': '79106', 'county': 'POTTER', 'city': 'AMARILLO'}
# --------
# {'name': 'NGUYEN, MYCAM THI', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20180011017', 'license': '734788', 'zipcode': '75043', 'county': 'DALLAS', 'city': 'GARLAND'}
# --------
# {'name': 'NGUYEN, THUYVI T', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.', 'complaint': 'COS20180014315', 'license': '784702', 'zipcode': '78660', 'county': 'TRAVIS', 'city': 'PFLUGERVILLE'}
# --------
# {'name': 'NGUYEN, OANH PHUONG', 'violations': 'Respondent was in possession of bottles containing methyl methacrylate monomer.', 'complaint': 'COS20180015729', 'license': '739546', 'zipcode': '76542', 'county': 'BELL', 'city': 'KILLEEN'}
# --------
# {'name': 'NGUYEN, QUANG Q', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'complaint': 'COS20180012060', 'license': '771954', 'zipcode': '88008', 'county': 'OUT OF STATE', 'city': 'SANTA TERESA'}
# --------
# {'name': 'NGUYEN, CINDY', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to ensure that only semi-permanent glue was used during eyelash extension services.', 'complaint': 'COS20180014267', 'license': '786409', 'zipcode': '78414', 'county': 'NUECES', 'city': 'CORPUS CHRISTI'}
# --------
# {'name': 'NGUYEN, KEVIN HOA', 'violations': "Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant after each client.", 'complaint': 'COS20180012949', 'license': '746655', 'zipcode': '91770', 'county': 'OUT OF STATE', 'city': 'ROSEMEAD'}
# --------
# {'name': 'NGUYEN, THUY T', 'violations': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.', 'complaint': 'COS20180014222', 'license': '720854', 'zipcode': '78003', 'county': 'BANDERA', 'city': 'BANDERA'}
# --------
# {'name': 'NGUYEN, THIENTRANG THI', 'violations': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to possess an autoclave, dry heat sterilizer or ultraviolet sanitizer.', 'complaint': 'COS20180010556', 'license': '783069, 1655219', 'zipcode': '78735', 'county': 'TRAVIS', 'city': 'AUSTIN'}
# --------
# {'name': 'NGUYEN, MARY ANN', 'violations': 'Respondent performed or attempted to perform a practice of cosmetology without a license.', 'complaint': 'COS20180014330', 'license': 'Not Licensed', 'zipcode': '78660', 'county': 'TRAVIS', 'city': 'PFLUGERVILLE'}
# --------
# {'name': 'NGUYEN, THANH CHUONG', 'violations': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.', 'complaint': 'COS20180007909', 'license': '748957, 1340920', 'zipcode': '75048', 'county': 'COLLIN', 'city': 'SACHSE'}
# --------
# {'name': 'NGUYEN, PHUONG N', 'violations': 'Respondent engaged in fraud or deceit in obtaining a certificate, license, or permit.', 'complaint': 'COS20180008524', 'license': '1199884, 1706073', 'zipcode': '77474', 'county': 'AUSTIN', 'city': 'SEALY'}
# --------
# {'name': 'NGUYEN, ANH TRAM', 'violations': 'Respondent failed to dispose of single use items after each use.', 'complaint': 'COS20180011108', 'license': '759616, 1475221, 1521294', 'zipcode': '77089', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------
# {'name': 'NGUYEN, HIEN', 'violations': 'Respondent performed or attempted to perform a practice of cosmetology without a license.', 'complaint': 'COS20180013126', 'license': 'Not Licensed', 'zipcode': '78602', 'county': 'BASTROP', 'city': 'BASTROP'}
# --------
# {'name': 'NGUYEN, TUAN A', 'violations': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.', 'complaint': 'COS20180008708', 'license': '681274', 'zipcode': '78723', 'county': 'TRAVIS', 'city': 'AUSTIN'}
# --------
# {'name': 'NGUYEN, LEON A', 'violations': "Respondent submitted a renewal application that made false statements regarding the Respondent's criminal history; Respondent has been convicted of a crime that was committed within 5 years of their renewal application; Respondent lacks sufficient honesty, trustworthiness and integrity to hold a license.", 'complaint': 'COS20180008891', 'license': '1173346', 'zipcode': '75048', 'county': 'COLLIN', 'city': 'SACHSE'}
# --------
# {'name': 'NGUYEN, VINH QUANG', 'violations': 'Respondent was in possession of bottles containing methyl methacrylate monomer.', 'complaint': 'COS20180012418', 'license': '712441', 'zipcode': '79901', 'county': 'EL PASO', 'city': 'EL PASO'}
# --------
# {'name': 'NGUYEN, BINH VAN', 'violations': 'Respondent was in possession of bottles containing methyl methacrylate monomer.', 'complaint': 'COS20180015790', 'license': '756644', 'zipcode': '76543', 'county': 'BELL', 'city': 'KILLEEN'}
# --------
# {'name': 'NGUYEN, SHARON', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.', 'complaint': 'COS20180013118', 'license': '750030', 'zipcode': '78602', 'county': 'BASTROP', 'city': 'BASTROP'}
# --------
# {'name': 'NGUYEN, BINH THANH', 'violations': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.', 'complaint': 'COS20180012368', 'license': '772744', 'zipcode': '78045', 'county': 'WEBB', 'city': 'LAREDO'}
# --------
# {'name': 'NGUYEN, SAMANTHA TRAN', 'violations': 'Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.', 'complaint': 'COS20180006595', 'license': '743492, 1279657, 1562243', 'zipcode': '75070', 'county': 'COLLIN', 'city': 'MCKINNEY'}
# --------
# {'name': 'NGUYEN, THU LE', 'violations': 'Respondent failed to comply with an order previously issued by the Executive Director.', 'complaint': 'COS20180007798', 'license': '11224436, 685119', 'zipcode': '78216', 'county': 'BEXAR', 'city': 'SAN ANTONIO'}
# --------
# {'name': 'NGUYEN, KIM NGAN THI', 'violations': 'Respondent interfered with a Department inspection of the salon.', 'complaint': 'COS2009004238D', 'license': '1434311', 'zipcode': '77084', 'county': 'HARRIS', 'city': 'HOUSTON'}
# --------

# %% [markdown]
# ### Save that to a CSV
#
# - Tip: Use `pd.DataFrame` to create a dataframe, and then save it to a CSV.

# %%
df = pd.DataFrame(rows)
df.head()
# Out:
#                 name                                         violations  \
# 0                NaN                                                NaN
# 1  NGUYEN, MIMI PHAM  Respondent failed properly clean and sanitize ...
# 2         NGUYEN, HA  Respondent failed to clean and sanitize four (...
# 3  NGUYEN, THAO HONG  Respondent failed to clean, disinfect, and ste...
# 4      NGUYEN, CINDY  Respondent failed to clean and disinfect all w...
#
#         complaint                   license zipcode   county            city
# 0             NaN                       NaN     NaN      NaN             NaN
# 1  COS20190010072                    784210   77449   HARRIS            KATY
# 2  COS20190016762                    764888   76017  TARRANT       ARLINGTON
# 3  COS20200010387           799926, 1753491   78238    BEXAR     SAN ANTONIO
# 4  COS20200010502  806232, 1260359, 1280071   78414   NUECES  CORPUS CHRISTI

# %%
df.to_csv("nguyen_licenses1.csv", index=False, header=True)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
df=pd.read_csv("nguyen_licenses1.csv")
df.head()
# Out:
#                 name                                         violations  \
# 0                NaN                                                NaN
# 1  NGUYEN, MIMI PHAM  Respondent failed properly clean and sanitize ...
# 2         NGUYEN, HA  Respondent failed to clean and sanitize four (...
# 3  NGUYEN, THAO HONG  Respondent failed to clean, disinfect, and ste...
# 4      NGUYEN, CINDY  Respondent failed to clean and disinfect all w...
#
#         complaint                   license  zipcode   county            city
# 0             NaN                       NaN      NaN      NaN             NaN
# 1  COS20190010072                    784210  77449.0   HARRIS            KATY
# 2  COS20190016762                    764888  76017.0  TARRANT       ARLINGTON
# 3  COS20200010387           799926, 1753491  78238.0    BEXAR     SAN ANTONIO
# 4  COS20200010502  806232, 1260359, 1280071  78414.0   NUECES  CORPUS CHRISTI

# %% [markdown]
# ## Let's do this an easier way
#
# Use Selenium and `pd.read_html` to get the table as a dataframe.

# %%
df2 = pd.read_html(driver.page_source)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-345b61c93213> in <module>
# ----> 1 df2 = pd.read_html(driver.page_source)
#
# NameError: name 'pd' is not defined
