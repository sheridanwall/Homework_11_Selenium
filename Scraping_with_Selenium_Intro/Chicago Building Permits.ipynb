# %% [markdown]
# ## Logging on
#
# Use Selenium to visit https://webapps1.chicago.gov/buildingrecords/ and accept the agreement.
#
# > Think about when you use `.find_element_...` and when you use `.find_elementSSS_...`

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://webapps1.chicago.gov/buildingrecords/')

# %%
driver.page_source
# Out:
# '<html lang="en"><head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n\n\t<!-- Global site tag (gtag.js) - Google Analytics -->\n\t<script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=UA-5653376-8&amp;l=dataLayer&amp;cx=c"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-5653376-2"></script>\n\t<script>\n\t  window.dataLayer = window.dataLayer || [];\n\t  function gtag(){dataLayer.push(arguments);}\n\t  gtag(\'js\', new Date());\n\t  gtag(\'config\', \'UA-5653376-8\');\t \n\t</script>\n\n    <title>Building Permit and Inspection Records: Agreement</title>\n\n    <!-- CSS -->\n\t<link href="https://webapps1.cityofchicago.org/cdn/Bootstrap-4.0.0-beta.2/css/bootstrap.min.css" rel="stylesheet">\n    <link href="https://webapps1.cityofchicago.org/cdn/jQuery-UI-1.12.1/jquery-ui.min.css" rel="stylesheet">\n    <link href="https://webapps1.cityofchicago.org/cdn/DataTables-1.10.16/css/dataTables.jqueryui.min.css" rel="stylesheet">\n\t<link href="https://webapps1.cityofchicago.org/cdn/Responsive-2.2.1/css/responsive.jqueryui.min.css" rel="stylesheet">\n    <link href="https://webapps1.cityofchicago.org/cdn/Bootstrap-ComboBox-1.1.8/bootstrap-combobox.css" rel="stylesheet">\n    <link href="https://webapps1.cityofchicago.org/cdn/TypeAhead-0.11.1/typeahead.css" rel="stylesheet">\n    <link href="https://webapps1.cityofchicago.org/cdn/City-1.0/city.css" rel="stylesheet">\n    <link href="https://webapps1.cityofchicago.org/cdn/MegaNavbar-2.2.0/skins/city.css" rel="stylesheet">\n    <link href="/buildingrecords/resources/FontAwesome-5.0.6/css/fontawesome-all.min.css" rel="stylesheet">\n    <link href="/buildingrecords/resources/City-1.0/application.css" rel="stylesheet">\n    <link href="https://fonts.googleapis.com/css?family=Open+Sans" rel="stylesheet" type="text/css">\n\t\n\t<!-- JavaScript -->\n\t<script src="https://webapps1.cityofchicago.org/cdn/jQuery-3.2.1/jquery-3.2.1.min.js"></script>\n\t<script src="https://webapps1.cityofchicago.org/cdn/jQuery-UI-1.12.1/jquery-ui.min.js"></script>\n\t<script src="https://webapps1.cityofchicago.org/cdn/Moment-2.18.1/moment.min.js"></script>\n\t<script src="https://webapps1.cityofchicago.org/cdn/DataTables-1.10.16/js/jquery.dataTables.min.js"></script>\n\t<script src="https://webapps1.cityofchicago.org/cdn/DataTables-1.10.16/js/dataTables.jqueryui.min.js"></script>\n\t<script src="https://webapps1.cityofchicago.org/cdn/Responsive-2.2.1/js/dataTables.responsive.min.js"></script>\n\t<script src="https://webapps1.cityofchicago.org/cdn/Responsive-2.2.1/js/responsive.jqueryui.min.js"></script>\n\t<script src="https://webapps1.cityofchicago.org/cdn/Bootstrap-ComboBox-1.1.8/bootstrap-combobox.js"></script>\n\t<script src="https://webapps1.cityofchicago.org/cdn/TypeAhead-0.11.1/typeahead.bundle.js"></script>\n\t<script src="https://webapps1.cityofchicago.org/cdn/TypeAhead-0.11.1/typeahead.jquery.js"></script>\n\t\t\n\t<link rel="Shortcut Icon" type="image/ico" href="/buildingrecords/resources/City-1.0/favicon-32x32.png">\n</head>\n\n<body>\n\n<div class="page-wrapper">\n\n\t<!-- Header -->\n\t<div class="container-fluid" style="margin-bottom:0px;margin-top:0px;padding-bottom:10px;padding-top:10px;padding-right:20px;padding-left:20px;background-color: #0198DD">\n\t\t<img class="img-fluid" src="/buildingrecords/resources/City-1.0/city-logo.png" alt="City of Chicago">\n\t</div>\n\t<!-- End Header -->\n\t\n\t<!--Narrow Header-->\n\t<div class="container-fluid app-header" style="padding-left:0px;padding-right:0px;"> \n\t\t<a href="/buildingrecords/home" title="The City of Chicago\'s Official Site">\n\t\t\t<img class="img-responsive" src="/buildingrecords/resources/City-1.0/banner.jpg" alt="Building Permit and Inspection Records" style= ...

# %%
driver.find_element_by_id("rbnAgreement1").click()

# %%
submit_button = driver.find_element_by_xpath('//*[@id="submit"]')
submit_button.click()

# %% [markdown]
# ## Searching
#
# Search for **400 E 41ST ST**.

# %%
textbox = driver.find_element_by_id("fullAddress")

# %%
textbox.send_keys("400 E 41ST ST.")

# %%
submit_button = driver.find_element_by_xpath('//*[@id="submit"]')

# %%
submit_button.click()

# %% [markdown]
# ## Saving tables with pandas
#
# Use pandas to save a CSV of all **permits** to `Permits - 400 E 41ST ST.csv`. Note that there are **different sections of the page**, not just one long permits table.

# %%
import pandas as pd
# Out:
# /Users/sheridanwall/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
tables = pd.read_html(driver.page_source)
tables[0]
# Out:
#      PERMIT #  DATE ISSUED                                DESCRIPTION OF WORK
# 0   100845718          NaN  ERECT TWO SCAFFOLDS FROM 10/14/2019 TO 10/14/2...
# 1   100778302          NaN  PERMIT EXPIRES ON 10/17/2018 Erection Starts: ...
# 2   100721255          NaN  PERMIT EXPIRES ON 10/24/2017 ERECTION STARTS: ...
# 3   100693399          NaN  INSTALLATION OF LOW VOLTAGE BURGLAR ALARM INTE...
# 4   100665436          NaN  PERMIT EXPIRES ON 10/24/2016 ERECTION STARTS: ...
# 5   100610771          NaN  PERMIT EXPIRES ON 10/28/2015 ERECTION STARTS: ...
# 6   100581991          NaN  TRACE AND REPAIR BROKEN UNDERGROUND FEED TO EX...
# 7   100479194          NaN     INTERNALLY LIT SIGN CABINET ON SOUTH ELEVATION
# 8   100385721          NaN  RPACE CONCRETE SLAB WITH NEW AT GROUNGD FLOOR ...
# 9   100267298          NaN  INTERIOR ALTERATIONS TO MEDICAL OFFICE SUITE 1...
# 10  100218969          NaN  Revision to Permit. Removing walls at elevator...
# 11  100195892          NaN  INTERIOR ALTERATIONS TO 1ST FLOOR TENANT SPACE...
# 12  100178678          NaN  WIRE ALL LOW VOLTAGE TEMPERATURE CONTROLS ALL ...
# 13  100154767          NaN  MODERNIZE FIVE (5) PASSENGER ELEVATORS AS PER ...
# 14  100153183          NaN       Renovation/Alterations to 19-story Tower #2.
# 15  100153182          NaN       Renovation/Alterations to 27-story Tower #1.
# 16  B20022113          NaN  1N REPAIR,PATCH, 908' LG CON TERRACE WALL ( 3 ...
# 17  EL1566941          NaN             INSTALL 3 HPS WALL FIXTURE ON BUILDING
# 18  B97033015          NaN  THREE (3) PASSENGER ELEVATORS ADAMS DOOR RESTR...
# 19  EL9445368          NaN           ADD 2-ADD'TL METER SOCKETS & 2-BRKR PNLS
# 20  EL9443103          NaN                      INSTALL PHONE SYSTEM (MERLIN)
# 21  EL8874529          NaN                INSTALL LOW VOLTAGE SECURITY SYSTEM
# 22  EL8770080          NaN                      100A SERVICE, 2-METER SOCKETS
# 23  EL7634958          NaN           6-15 AMP 2-WIRE CKTS AND SIX (6) FIXTURS
# 24  EL7393792          NaN                LOW VOLTAGE PHONE SYSTEM EQUITY 111
# 25  ES3148854          NaN                                                NaN
# 26  EL6455110          NaN                  INSTALL 278 OUTLETS ON EXIST CIRC
# 27  EL6345593          NaN             STANLEY MAGIC DOOR EQUIPT INSTALLATION
# 28  EL6242147          NaN                  2000A SERV, 400A SERV, 200A SERV,
# 29  EL6196217          NaN                                       400A SERVICE
# 30  EL5912649          NaN                         ADD FEE TO PERMIT #5764111
# 31  EL5764118          NaN                                       400A SERVICE

# %%
tables[0].to_csv(r'/Users/sheridanwall/Documents/Foundations/Permits_400_E_41ST_ST.csv', index = False)

# %% [markdown]
# ## Saving tables the long way
#
# Save a CSV of all DOB inspections to `Inspections - 400 E 41ST ST.csv`, but **you also need to save the URL to the inspection**. As a result, you won't be able to use pandas, you'll need to use a loop and create a list of dictionaries.
#
# You can use Selenium (my recommendation) or you can feed the source to BeautifulSoup. You should have approximately 157 rows.
#
# You'll probably need to find the table first, then the rows inside, then the cells inside of each row. You'll probably use lots of list indexing. I might recommend XPath for finding the table.
#
# *Tip: If you get a "list index out of range" error, it's probably due to an issue involving `thead` vs `tbody` elements. What are they? What are they for? What's in them? There are a few ways to troubleshoot it.*

# %%
items = driver.find_elements_by_id('resultstable_inspections')
for item in items:
    insp_table= item.find_elements_by_tag_name('tbody')
    for insp in insp_table:
        cells = insp.find_elements_by_tag_name('tr')
        for cell in cells:
            number = cell.find_elements_by_tag_name('td')[0].text
            print(number)
            date = cell.find_elements_by_tag_name('td')[1].text
            print(date)
            status = cell.find_elements_by_tag_name('td')[2].text
            print(status)
            description = cell.find_elements_by_tag_name('td')[3].text
            print(description)
# Out:
# 13175960
# 11/30/2020
# FAILED
# ANNUAL INSPECTION
# 12770690
# 05/30/2019
# PASSED
# BOILER ANNUAL INSPECTION
# 12670542
# 05/21/2019
# FAILED
# CONSERVATION ANNUAL
# 12277260
# 08/27/2018
# FAILED
# CONSERVATION ANNUAL
# 12418304
# 05/30/2018
# PASSED
# BOILER ANNUAL INSPECTION
# 12136453
# 06/21/2017
# PASSED
# ANNUAL INSPECTION
# 12226018
# 06/21/2017
# PASSED
# ANNUAL INSPECTION
# 11228963
# 06/19/2017
# FAILED
# CONSERVATION ANNUAL
# 12101602
# 04/21/2017
# PASSED
# ANNUAL INSPECTION
# 12214968
# 03/22/2017
# PASSED
# SIGN ANNUAL INSPECTION
# 12051724
# 12/21/2016
# FAILED
# CONSERVATION COMPLAINT INSPECT
# 11750904
# 11/03/2016
# PASSED
# BOILER ANNUAL INSPECTION
# 11986288
# 09/01/2016
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1749666
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1664779
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1664784
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613903
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613910
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613898
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613905
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1113224
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1340193
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1332657
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1396179
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1242229
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1064281
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=833206
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=965745
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=916641
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=951019
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=745379
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=779987
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=734609
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=577179
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=495435
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=251124
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=465051
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=417334
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=458503
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=440211
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=200272
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=707841
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=251273
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=245364
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=175477
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=9639744
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=130127
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=25836
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=130126
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=9475223
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=9457580
# https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=130125

# %%
inspections = []
items = driver.find_elements_by_id('resultstable_inspections')
for item in items:
    insp_table= item.find_elements_by_tag_name('tbody')
    for insp in insp_table:
        cells = insp.find_elements_by_tag_name('tr')
        for cell in cells:
            inspection = {}
            inspection['number'] = cell.find_elements_by_tag_name('td')[0].text
            inspection['date'] = cell.find_elements_by_tag_name('td')[1].text
            inspection['status'] = cell.find_elements_by_tag_name('td')[2].text
            inspection['description'] = cell.find_elements_by_tag_name('td')[3].text
            links = cell.find_elements_by_tag_name('a')
            for link in links:
                inspection['urls'] = link.get_attribute('href')
            print(inspection)
            inspections.append(inspection)
# Out:
# {'number': '13175960', 'date': '11/30/2020', 'status': 'FAILED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=13175960'}
# {'number': '12770690', 'date': '05/30/2019', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=12770690'}
# {'number': '12670542', 'date': '05/21/2019', 'status': 'FAILED', 'description': 'CONSERVATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=12670542'}
# {'number': '12277260', 'date': '08/27/2018', 'status': 'FAILED', 'description': 'CONSERVATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=12277260'}
# {'number': '12418304', 'date': '05/30/2018', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=12418304'}
# {'number': '12136453', 'date': '06/21/2017', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=12136453'}
# {'number': '12226018', 'date': '06/21/2017', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=12226018'}
# {'number': '11228963', 'date': '06/19/2017', 'status': 'FAILED', 'description': 'CONSERVATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11228963'}
# {'number': '12101602', 'date': '04/21/2017', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=12101602'}
# {'number': '12214968', 'date': '03/22/2017', 'status': 'PASSED', 'description': 'SIGN ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=12214968'}
# {'number': '12051724', 'date': '12/21/2016', 'status': 'FAILED', 'description': 'CONSERVATION COMPLAINT INSPECT', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=12051724'}
# {'number': '11750904', 'date': '11/03/2016', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11750904'}
# {'number': '11986288', 'date': '09/01/2016', 'status': 'PASSED', 'description': 'REFRIGERATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11986288'}
# {'number': '11787131', 'date': '08/24/2016', 'status': 'PASSED', 'description': 'REFRIGERATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11787131'}
# {'number': '11835125', 'date': '08/02/2016', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11835125'}
# {'number': '11933971', 'date': '08/02/2016', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11933971'}
# {'number': '11413712', 'date': '10/23/2015', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11413712'}
# {'number': '11623884', 'date': '08/28/2015', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11623884'}
# {'number': '11014536', 'date': '07/28/2015', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11014536'}
# {'number': '11244373', 'date': '07/28/2015', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11244373'}
# {'number': '11542833', 'date': '07/20/2015', 'status': 'PASSED', 'description': 'SIGN ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11542833'}
# {'number': '11598664', 'date': '06/02/2015', 'status': 'FAILED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11598664'}
# {'number': '11497331', 'date': '05/20/2015', 'status': 'FAILED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11497331'}
# {'number': '11224848', 'date': '02/27/2015', 'status': 'FAILED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11224848'}
# {'number': '11074793', 'date': '10/15/2014', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11074793'}
# {'number': '10934450', 'date': '09/19/2014', 'status': 'PASSED', 'description': 'STRUCTURAL SIGN INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10934450'}
# {'number': '10934449', 'date': '09/19/2014', 'status': 'PASSED', 'description': 'SIGN PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10934449'}
# {'number': '10995934', 'date': '04/04/2014', 'status': 'FAILED', 'description': 'CONSERVATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10995934'}
# {'number': '10895288', 'date': '12/18/2013', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10895288'}
# {'number': '10789690', 'date': '12/04/2013', 'status': 'PASSED', 'description': 'REFRIGERATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10789690'}
# {'number': '10775620', 'date': '10/22/2013', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10775620'}
# {'number': '10912983', 'date': '10/01/2013', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10912983'}
# {'number': '11002791', 'date': '10/01/2013', 'status': 'FAILED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=11002791'}
# {'number': '10715924', 'date': '08/21/2013', 'status': 'FAILED', 'description': 'CONSERVATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10715924'}
# {'number': '10270889', 'date': '10/16/2012', 'status': 'FAILED', 'description': 'CONSERVATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10270889'}
# {'number': '10681952', 'date': '08/28/2012', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10681952'}
# {'number': '10740771', 'date': '08/28/2012', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10740771'}
# {'number': '10560743', 'date': '05/23/2012', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10560743'}
# {'number': '9995366', 'date': '04/09/2012', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=9995366'}
# {'number': '10411517', 'date': '03/07/2012', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10411517'}
# {'number': '10530867', 'date': '02/21/2012', 'status': 'FAILED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10530867'}
# {'number': '10230414', 'date': '10/27/2011', 'status': 'FAILED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10230414'}
# {'number': '10167186', 'date': '09/12/2011', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10167186'}
# {'number': '10155814', 'date': '07/13/2011', 'status': 'PASSED', 'description': 'VENT ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10155814'}
# {'number': '9952632', 'date': '05/05/2011', 'status': 'FAILED', 'description': 'CONSERVATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=9952632'}
# {'number': '10089951', 'date': '02/22/2011', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10089951'}
# {'number': '10002293', 'date': '01/12/2011', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10002293'}
# {'number': '10002295', 'date': '01/12/2011', 'status': 'FAILED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=10002295'}
# {'number': '2374203', 'date': '10/04/2010', 'status': 'PASSED', 'description': 'REFRIGERATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2374203'}
# {'number': '9974938', 'date': '09/09/2010', 'status': 'FAILED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=9974938'}
# {'number': '2677167', 'date': '09/09/2010', 'status': 'FAILED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2677167'}
# {'number': '9762140', 'date': '09/02/2010', 'status': 'FAILED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=9762140'}
# {'number': '9959603', 'date': '06/30/2010', 'status': 'FAILED', 'description': 'CONSERVATION COMPLAINT INSPECT', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=9959603'}
# {'number': '2688652', 'date': '06/15/2010', 'status': 'FAILED', 'description': 'CONSERVATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2688652'}
# {'number': '9748377', 'date': '02/11/2010', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=9748377'}
# {'number': '2354095', 'date': '12/29/2009', 'status': 'PASSED', 'description': 'PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2354095'}
# {'number': '2639899', 'date': '08/21/2009', 'status': 'PASSED', 'description': 'VENT ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2639899'}
# {'number': '1896682', 'date': '07/27/2009', 'status': 'CLOSED', 'description': 'ELECTRICAL PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1896682'}
# {'number': '2565707', 'date': '03/25/2009', 'status': 'PASSED', 'description': 'DOB PLUMBING INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2565707'}
# {'number': '2408216', 'date': '03/25/2009', 'status': 'PASSED', 'description': 'DOB NEW CONSTRUCTION INSP', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2408216'}
# {'number': '2576872', 'date': '03/25/2009', 'status': 'PASSED', 'description': 'DOB VENT/FURNACE INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2576872'}
# {'number': '2576870', 'date': '03/25/2009', 'status': 'PASSED', 'description': 'ELECTRICAL PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2576870'}
# {'number': '2648465', 'date': '03/04/2009', 'status': 'FAILED', 'description': 'CONSERVATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2648465'}
# {'number': '2559724', 'date': '01/30/2009', 'status': 'PASSED', 'description': 'DOB VENT/FURNACE INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2559724'}
# {'number': '2408214', 'date': '01/30/2009', 'status': 'PARTIAL PASSED', 'description': 'DOB VENT/FURNACE INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2408214'}
# {'number': '2408213', 'date': '01/30/2009', 'status': 'PARTIAL PASSED', 'description': 'ELECTRICAL PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2408213'}
# {'number': '2559720', 'date': '01/29/2009', 'status': 'PASSED', 'description': 'DOB VENT/FURNACE INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2559720'}
# {'number': '2565706', 'date': '01/26/2009', 'status': 'PARTIAL PASSED', 'description': 'DOB PLUMBING INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2565706'}
# {'number': '2008609', 'date': '01/23/2009', 'status': 'PASSED', 'description': 'CONSTRUCTION EQUIPMENT PERMIT', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2008609'}
# {'number': '2561851', 'date': '01/21/2009', 'status': 'PASSED', 'description': 'BOILER PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2561851'}
# {'number': '2561850', 'date': '01/21/2009', 'status': 'PASSED', 'description': 'BOILER PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2561850'}
# {'number': '2561849', 'date': '01/21/2009', 'status': 'PASSED', 'description': 'BOILER PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2561849'}
# {'number': '2564084', 'date': '01/21/2009', 'status': 'PASSED', 'description': 'BOILER PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2564084'}
# {'number': '2510789', 'date': '01/21/2009', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2510789'}
# {'number': '1840048', 'date': '01/15/2009', 'status': 'PASSED', 'description': 'BLDG_PERM IRON PERMIT INSP', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1840048'}
# {'number': '1839870', 'date': '01/15/2009', 'status': 'PASSED', 'description': 'BLDG_PERM IRON PERMIT INSP', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1839870'}
# {'number': '2017660', 'date': '01/15/2009', 'status': 'PASSED', 'description': 'DOB NEW CONSTRUCTION INSP', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2017660'}
# {'number': '2017661', 'date': '01/15/2009', 'status': 'PASSED', 'description': 'DOB NEW CONSTRUCTION INSP', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2017661'}
# {'number': '2020266', 'date': '01/15/2009', 'status': 'PASSED', 'description': 'DOB NEW CONSTRUCTION INSP', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2020266'}
# {'number': '1613901', 'date': '01/15/2009', 'status': 'PARTIAL PASSED', 'description': 'DOB VENT/FURNACE INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613901'}
# {'number': '1613908', 'date': '01/15/2009', 'status': 'PARTIAL PASSED', 'description': 'DOB VENT/FURNACE INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613908'}
# {'number': '2020265', 'date': '01/15/2009', 'status': 'PASSED', 'description': 'DOB VENT/FURNACE INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2020265'}
# {'number': '2314825', 'date': '01/15/2009', 'status': 'PASSED', 'description': 'DOB PLUMBING INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2314825'}
# {'number': '1613906', 'date': '01/15/2009', 'status': 'PASSED', 'description': 'DOB PLUMBING INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613906'}
# {'number': '1613897', 'date': '01/15/2009', 'status': 'PASSED', 'description': 'ELECTRICAL PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613897'}
# {'number': '1613904', 'date': '01/15/2009', 'status': 'PASSED', 'description': 'ELECTRICAL PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613904'}
# {'number': '2020263', 'date': '01/15/2009', 'status': 'PASSED', 'description': 'ELECTRICAL PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2020263'}
# {'number': '2020264', 'date': '01/15/2009', 'status': 'PASSED', 'description': 'DOB PLUMBING INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2020264'}
# {'number': '1613907', 'date': '12/31/2008', 'status': 'PASSED', 'description': 'DOB REFRIGERATION INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613907'}
# {'number': '1613900', 'date': '12/31/2008', 'status': 'PASSED', 'description': 'DOB REFRIGERATION INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613900'}
# {'number': '2391718', 'date': '11/25/2008', 'status': 'PASSED', 'description': 'PUMP ACCEPTANCE TEST', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2391718'}
# {'number': '2566069', 'date': '11/25/2008', 'status': 'PASSED', 'description': 'PUMP ACCEPTANCE TEST', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2566069'}
# {'number': '2119488', 'date': '10/22/2008', 'status': 'FAILED', 'description': 'REFRIGERATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2119488'}
# {'number': '2261834', 'date': '08/29/2008', 'status': 'PARTIAL PASSED', 'description': 'PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2261834'}
# {'number': '2314122', 'date': '07/11/2008', 'status': 'PARTIAL PASSED', 'description': 'DOB PLUMBING INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2314122'}
# {'number': '1894630', 'date': '07/08/2008', 'status': 'PARTIAL PASSED', 'description': 'DOB PLUMBING INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1894630'}
# {'number': '2168070', 'date': '06/02/2008', 'status': 'PASSED', 'description': 'CONSERVATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2168070'}
# {'number': '2154189', 'date': '05/14/2008', 'status': 'PASSED', 'description': 'VENT ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2154189'}
# {'number': '2074609', 'date': '04/09/2008', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2074609'}
# {'number': '2091277', 'date': '04/04/2008', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2091277'}
# {'number': '1966669', 'date': '02/27/2008', 'status': 'PARTIAL PASSED', 'description': 'PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1966669'}
# {'number': '1613902', 'date': '11/01/2007', 'status': 'PARTIAL PASSED', 'description': 'DOB NEW CONSTRUCTION INSP', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613902'}
# {'number': '1871104', 'date': '11/01/2007', 'status': 'PARTIAL PASSED', 'description': 'DOB NEW CONSTRUCTION INSP', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1871104'}
# {'number': '1943916', 'date': '08/15/2007', 'status': 'PARTIAL PASSED', 'description': 'PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1943916'}
# {'number': '1973677', 'date': '07/31/2007', 'status': 'PARTIAL PASSED', 'description': 'CONSTRUCTION EQUIPMENT PERMIT', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1973677'}
# {'number': '1951026', 'date': '07/31/2007', 'status': 'PARTIAL PASSED', 'description': 'CONSTRUCTION EQUIPMENT PERMIT', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1951026'}
# {'number': '2008607', 'date': '07/31/2007', 'status': 'PARTIAL PASSED', 'description': 'CONSTRUCTION EQUIPMENT PERMIT', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=2008607'}
# {'number': '1937982', 'date': '07/13/2007', 'status': 'PARTIAL PASSED', 'description': 'CONSTRUCTION EQUIPMENT PERMIT', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1937982'}
# {'number': '1957863', 'date': '07/13/2007', 'status': 'PASSED', 'description': 'CONSTRUCTION EQUIPMENT PERMIT', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1957863'}
# {'number': '1768615', 'date': '06/21/2007', 'status': 'PASSED', 'description': 'CONSERVATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1768615'}
# {'number': '1912893', 'date': '06/13/2007', 'status': 'PARTIAL PASSED', 'description': 'CONSTRUCTION EQUIPMENT PERMIT', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1912893'}
# {'number': '1882042', 'date': '05/25/2007', 'status': 'PARTIAL PASSED', 'description': 'CONSTRUCTION EQUIPMENT PERMIT', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1882042'}
# {'number': '1621186', 'date': '05/16/2007', 'status': 'PARTIAL PASSED', 'description': 'PERMIT INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1621186'}
# {'number': '1613899', 'date': '05/10/2007', 'status': 'PARTIAL PASSED', 'description': 'DOB PLUMBING INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613899'}
# {'number': '1881043', 'date': '04/20/2007', 'status': 'PARTIAL PASSED', 'description': 'CONSTRUCTION EQUIPMENT PERMIT', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1881043'}
# {'number': '1652466', 'date': '04/06/2007', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1652466'}
# {'number': '1613909', 'date': '04/06/2007', 'status': 'PARTIAL PASSED', 'description': 'DOB NEW CONSTRUCTION INSP', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613909'}
# {'number': '1749666', 'date': '03/08/2007', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1749666'}
# {'number': '1664779', 'date': '02/13/2007', 'status': 'PARTIAL PASSED', 'description': 'BLDG_PERM IRON PERMIT INSP', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1664779'}
# {'number': '1664784', 'date': '02/13/2007', 'status': 'PARTIAL PASSED', 'description': 'BLDG_PERM IRON PERMIT INSP', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1664784'}
# {'number': '1613903', 'date': '02/07/2007', 'status': 'PARTIAL PASSED', 'description': 'CONSTRUCTION EQUIPMENT PERMIT', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613903'}
# {'number': '1613910', 'date': '02/05/2007', 'status': 'PARTIAL PASSED', 'description': 'CONSTRUCTION EQUIPMENT PERMIT', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613910'}
# {'number': '1613898', 'date': '12/21/2006', 'status': 'PARTIAL PASSED', 'description': 'BLDG_PERM IRON PERMIT INSP', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613898'}
# {'number': '1613905', 'date': '12/21/2006', 'status': 'PARTIAL PASSED', 'description': 'BLDG_PERM IRON PERMIT INSP', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1613905'}
# {'number': '1113224', 'date': '12/13/2006', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1113224'}
# {'number': '1340193', 'date': '08/25/2006', 'status': 'PASSED', 'description': 'REFRIGERATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1340193'}
# {'number': '1332657', 'date': '06/20/2006', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1332657'}
# {'number': '1396179', 'date': '06/01/2006', 'status': 'PASSED', 'description': 'VENT ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1396179'}
# {'number': '1242229', 'date': '03/10/2006', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1242229'}
# {'number': '1064281', 'date': '07/14/2005', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=1064281'}
# {'number': '833206', 'date': '06/29/2005', 'status': 'PASSED', 'description': 'REFRIGERATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=833206'}
# {'number': '965745', 'date': '06/25/2005', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=965745'}
# {'number': '916641', 'date': '06/17/2005', 'status': 'PASSED', 'description': 'CONSERVATION ANNUAL', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=916641'}
# {'number': '951019', 'date': '03/21/2005', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=951019'}
# {'number': '745379', 'date': '07/08/2004', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=745379'}
# {'number': '779987', 'date': '07/08/2004', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=779987'}
# {'number': '734609', 'date': '06/07/2004', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=734609'}
# {'number': '577179', 'date': '02/20/2004', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=577179'}
# {'number': '495435', 'date': '07/07/2003', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=495435'}
# {'number': '251124', 'date': '06/25/2003', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=251124'}
# {'number': '465051', 'date': '06/25/2003', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=465051'}
# {'number': '417334', 'date': '05/30/2003', 'status': 'PASSED', 'description': 'SIGN ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=417334'}
# {'number': '458503', 'date': '03/05/2003', 'status': 'FAILED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=458503'}
# {'number': '440211', 'date': '02/10/2003', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=440211'}
# {'number': '200272', 'date': '10/02/2002', 'status': 'PASSED', 'description': 'SIGN ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=200272'}
# {'number': '707841', 'date': '10/02/2002', 'status': 'CLOSED', 'description': 'SIGN ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=707841'}
# {'number': '251273', 'date': '07/11/2002', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=251273'}
# {'number': '245364', 'date': '07/10/2002', 'status': 'PASSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=245364'}
# {'number': '175477', 'date': '02/16/2002', 'status': 'PASSED', 'description': 'BOILER ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=175477'}
# {'number': '9639744', 'date': '12/22/2001', 'status': 'CLOSED', 'description': 'ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=9639744'}
# {'number': '130127', 'date': '08/20/2001', 'status': 'CLOSED', 'description': 'FIRE PREVENTION PUMPS LEGACY', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=130127'}
# {'number': '25836', 'date': '07/09/2001', 'status': 'PASSED', 'description': 'SIGN ANNUAL INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=25836'}
# {'number': '130126', 'date': '05/09/1997', 'status': 'CLOSED', 'description': 'FIRE PREVENTION PUMPS LEGACY', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=130126'}
# {'number': '9475223', 'date': '01/28/1997', 'status': 'CLOSED', 'description': 'ELEVATOR LEGACY INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=9475223'}
# {'number': '9457580', 'date': '01/21/1997', 'status': 'CLOSED', 'description': 'ELEVATOR LEGACY INSPECTION', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=9457580'}
# {'number': '130125', 'date': '03/21/1996', 'status': 'CLOSED', 'description': 'FIRE PREVENTION PUMPS LEGACY', 'urls': 'https://webapps1.chicago.gov/buildingrecords/inspectiondetails?addr=364923&insp=130125'}

# %%
df = pd.DataFrame(inspections)
df.head()
# Out:
#      number        date  status               description  \
# 0  13175960  11/30/2020  FAILED         ANNUAL INSPECTION
# 1  12770690  05/30/2019  PASSED  BOILER ANNUAL INSPECTION
# 2  12670542  05/21/2019  FAILED       CONSERVATION ANNUAL
# 3  12277260  08/27/2018  FAILED       CONSERVATION ANNUAL
# 4  12418304  05/30/2018  PASSED  BOILER ANNUAL INSPECTION
#
#                                                 urls
# 0  https://webapps1.chicago.gov/buildingrecords/i...
# 1  https://webapps1.chicago.gov/buildingrecords/i...
# 2  https://webapps1.chicago.gov/buildingrecords/i...
# 3  https://webapps1.chicago.gov/buildingrecords/i...
# 4  https://webapps1.chicago.gov/buildingrecords/i...

# %%
df.to_csv("Inspections_400_E41_ST.csv")

# %% [markdown]
# ### Loopity loops
#
# > If you used Selenium for the last question, copy the code and use it as a starting point for what we're about to do!
#
# If you click the inspection number, it'll open up a new window that shows you details of the violations from that visit. Count the number of violations for each visit and save it in a new column called **num_violations**.
#
# Save this file as `Inspections - 400 E 41ST ST - with counts.csv`.
#
# Since it opens in a new window, we have to say "Hey Selenium, pay attention to that new window!" We do that with `driver.switch_to.window(driver.window_handles[-1])` (each window gets a `window_handle`, and we're just asking the driver to switch to the last one.). A rough sketch of what your code will look like is here:
#
# ```python
# # Click the link that opens the new window
#
# # Switch to the new window/tab
# driver.switch_to.window(driver.window_handles[-1])
#
# # Do your scraping in here
#
# # Close the new window/tab
# driver.close()
#
# # Switch back to the original window/tab
# driver.switch_to.window(driver.window_handles[0])
# ```
#
# You'll want to play around with them individually before you try it with the whole set - the ones that pass are very different pages than the ones with violations! There are a few ways to get the number of violations, some easier than others.

# %%
for item in items:
    insp_table= item.find_elements_by_tag_name('tbody')
    for insp in insp_table:
        cells = insp.find_elements_by_tag_name('tr')
        for cell in cells:
            links = cell.find_elements_by_tag_name('a')
            for link in links:
                link.click()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-21-e6f5c4ab3b18> in <module>
#       1 for item in items:
# ----> 2     insp_table= item.find_elements_by_tag_name('tbody')
#       3     for insp in insp_table:
#       4         cells = insp.find_elements_by_tag_name('tr')
#       5         for cell in cells:
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in find_elements_by_tag_name(self, name)
#     318             elements = element.find_elements_by_tag_name('h1')
#     319         """
# --> 320         return self.find_elements(by=By.TAG_NAME, value=name)
#     321
#     322     def find_element_by_xpath(self, xpath):
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in find_elements(self, by, value)
#     682                 value = '[name="%s"]' % value
#     683
# --> 684         return self._execute(Command.FIND_CHILD_ELEMENTS,
#     685                              {"using": by, "value": value})['value']
#     686
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=87.0.4280.88)
